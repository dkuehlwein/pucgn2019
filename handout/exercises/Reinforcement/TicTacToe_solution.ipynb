# %% [markdown]
# # 1. Install dependencies

# %%
# !pip install keras-rl
# !pip install gym
# Out:
# Requirement already satisfied: keras-rl in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (0.4.2)
# Requirement already satisfied: keras>=2.0.7 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from keras-rl) (2.2.2)
# Requirement already satisfied: numpy>=1.9.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from keras>=2.0.7->keras-rl) (1.15.1)
# Requirement already satisfied: keras-applications==1.0.4 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from keras>=2.0.7->keras-rl) (1.0.4)
# Requirement already satisfied: scipy>=0.14 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from keras>=2.0.7->keras-rl) (1.1.0)
# Requirement already satisfied: keras-preprocessing==1.0.2 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from keras>=2.0.7->keras-rl) (1.0.2)
# Requirement already satisfied: pyyaml in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from keras>=2.0.7->keras-rl) (3.12)
# Requirement already satisfied: six>=1.9.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from keras>=2.0.7->keras-rl) (1.11.0)
# Requirement already satisfied: h5py in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from keras>=2.0.7->keras-rl) (2.8.0)
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: gym in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (0.10.5)
# Requirement already satisfied: requests>=2.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from gym) (2.18.4)
# Requirement already satisfied: numpy>=1.10.4 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from gym) (1.15.1)
# Requirement already satisfied: pyglet>=1.2.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from gym) (1.3.2)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from gym) (1.11.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from requests>=2.0->gym) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from requests>=2.0->gym) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from requests>=2.0->gym) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from requests>=2.0->gym) (2018.8.24)
# Requirement already satisfied: future in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from pyglet>=1.2.0->gym) (0.16.0)
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# # 2.1. Declare classes: AI Classes: Random AI, Minimax AI

# %%
import random

class RandomAI:

    def __init__(self, game):
        self.game = game

    def decide_turn(self):
        board = self.game.board
        assert sum([1 for cell in board.flatten() if cell == 0]) > 0, "no place to make a turn!!!"

        coords = [0,1,2]
        row = random.choice(coords)
        column = random.choice(coords)

        while board[row, column] != 0:
            row = random.choice(coords)
            column = random.choice(coords)

        return row, column

# %%
from math import inf as infinity

class MinimaxAI:

    def __init__(self, game):
        self.game = game
        self.random_ai = RandomAI(game)

    def decide_turn(self):
        turns_possible = self.empty_cells()
        if len(turns_possible) == 1:
            row, column = turns_possible[0]
        elif len(turns_possible) >= 7:
            row, column = self.random_ai.decide_turn()
        else:
            chosen_node = self.minimax(10, self.game.x_next)
            row, column, _ = chosen_node
        return row, column

    def empty_cells(self):
        state = self.game.board
        results = []
        for row in range(3):
            for column in range(3):
                if state[row, column] == 0:
                    results.append((row, column))

        return results

    def minimax(self,depth, X_turn):
        state = self.game.board
        score = self.game.evaluate(state)
        game_over = score is not None

        if depth == 0 or game_over:
            return [-1, -1, score]

        if X_turn:
            best = [-1, -1, -infinity]
        else:
            best = [-1, -1, +infinity]

        for cell in self.empty_cells():
            x, y = cell[0], cell[1]
            self.game.board[x, y] = 1 if X_turn else -1
            score = self.minimax(depth - 1, not X_turn)
            self.game.board[x, y] = 0
            score[0], score[1] = x, y

            if X_turn:
                if score[2] > best[2]:
                    best = score  # max value
            else:
                if score[2] < best[2]:
                    best = score  # min value

        return best

# %% [markdown]
# # 2.2. Environment class - the actual game implementation

# %%
# DEFINE THE TTT GAME CLASS

import numpy as np
import random
from functools import lru_cache
from gym.core import Env
from gym import spaces

class TicTacToe(Env):

    def __init__(self):
        self.board = np.zeros([3,3], dtype=np.int8)
        self.x_next = True if random.random() > 0.5 else False

        # by design, our AI plays x and the hard-coded AI plays for o
        self.x_ai = None
        self.o_ai = MinimaxAI(self)

        # action space consists of 9 distinct actions - trying to place your shape to each of 9 cells.
        self.action_space = spaces.Discrete(9)

        # observation space is the state of the board, as numpy array with possible values of
        # -1 - cell with 'o',
        # 0  - empty cell,
        # 1  - cell with 'x'
        self.observation_space = spaces.Box(low=-1, high=1, dtype=np.int8, shape=(3,3))


    def reset(self):
        """
        Resets the board for the next game. Starting player is random.
        """
        self.board = np.zeros([3, 3])
        self.x_next = True if random.random() > 0.5 else False
        if not self.x_next:
            row, column = self.o_ai.decide_turn()
            assert self.try_make_turn(row, column)

        return self.board

    def step(self, action):
        """
        TODO this method is not complete. its up to you to finish it.
        :param action: a discrete action from 0 to 8. Cells are enumerated from left to right,
        with columns continuing from top to bottom, like below:

         0 | 1 | 2
        -  + - + -
         3 | 4 | 5
        -  + - + -
         6 | 7 | 8

        if invalid action is used, board does not change, but negative reward is returned.
        :return: observation, reward, done?, info (empty)
        """
        assert self.x_next
        row = action // 3
        column = action % 3
        info = {}

        valid_turn = self.try_make_turn(row,column)
        if valid_turn:
            result = self.evaluate(self.board)
            if result is None:
                row, column = self.o_ai.decide_turn()
                assert self.try_make_turn(row, column)
                result = self.evaluate(self.board)

            if result is None:
                return self.board, 0, False, info
            else:
                return self.board, result, True, info

        else:
            return self.board, -1.5, True, info


    def try_make_turn(self, row, column):
        """
        The current player according to the boolean self.x_next tries to make a turn
        by placing their shape on the crossection of the crossection of :param row and :param column
        :return: True if it was a valid turn, False if such turn is not allowed (the cell is not empty).
        """

        if self.board[row,column] == 0:

            self.board[row, column] = 1 if self.x_next else -1
            self.x_next = not self.x_next
            return True

        else:
            return False

    @staticmethod
    def evaluate(board):
        """
        takes a :param board as the input ([3,3] numpy array),
        :return:
            None if the game is not over,
            1 if x won,
            -1 if o won,
            0 if its a draw
        """
        board_as_tuple = tuple(tuple(board[row]) for row in range(3))
        return TicTacToe._evaluate(board_as_tuple)

    def play_ai_game(self):
        while self.evaluate(self.board) is None:
            ai = self.x_ai if self.x_next else self.o_ai
            row, column = ai.decide_turn()
            valid_turn = self.try_make_turn(row, column)
            if not valid_turn:
                # any AI that makes invalid turn immediately loses the game.
                return -1 if self.x_next else 1
        return self.evaluate(self.board)

    @property
    def board_as_tuple(self):
        return tuple(tuple(self.board[row]) for row in range(3))


    @staticmethod
    @lru_cache(maxsize=2**16)
    def _evaluate(board):

        sums = []
        # we collect totals of all row, columns and diagonals. Any of those must have a value of
        # either 3 or -3 if there are x x x or o o o in this sequence.
        sums += [sum(board[row]) for row in range(3)]
        sums += [sum([board[i][column] for i in range(3)]) for column in range(3)]
        sum_main_diag = sum([board[i][i] for i in range(3)])
        sum_opp_diag = sum([board[i][2 - i] for i in range(3)])

        sums.append(sum_main_diag)
        sums.append(sum_opp_diag)
        
        n_steps = sum(abs(elem) for row in board for elem in row)

        if 3 in sums:
            return 1 - n_steps / 100
        elif -3 in sums:
            return -1 + n_steps / 100
        else:
            n_empty = sum([1 for row in range(3) for cell in board[row] if cell == 0])
            if n_empty == 0:
                return 0
            else:
                return None


    def play_vs_human(self):
        print("Welcome to Tic-Tac-Toe. Your opponent is a minimax AI, who makes first turn randomly. \n"
              "Use numbers from 0 to 8 to make turns. Below is the map of numbers to cells.")
        print("""
         0 | 1 | 2
        -  + - + -
         3 | 4 | 5
        -  + - + -
         6 | 7 | 8""")
        "You play for x, your opponent plays for o"
        self.reset()
        done = False
        while not done:
            try:
                self.render()
                action = int(input(">>> "))
            except:
                print("could not parse your input. Please try again. Use numbers from 0 to 8 to make turns.")
            else:
                row = action // 3
                column = action % 3

                valid_turn = self.try_make_turn(row, column)
                if not valid_turn:
                    print("Unfortunately you can't overwrite existing shapes. \n"
                          "You have made an invalid turn and therefore lost the game.")
                    break

                result = self.evaluate(self.board)

                if result is not None:
                    self.render()
                    if result == 1:
                        print("Congratulations! you have won the game!")
                    elif result == 0:
                        print("The game has ended in a draw.")
                    break

                row, column = self.o_ai.decide_turn()
                assert self.try_make_turn(row, column)
                result = self.evaluate(self.board)

                if result is not None:
                    self.render()
                    if result == -1:
                        print("Minimax AI has won the game.")
                    elif result == 0:
                        print("The game has ended in a draw.")
                    break


        print("Thanks for playing Tic-Tac-Toe. Have a nice day and come back any time!")


    def render(self, mode="Human"):
        shapes = {-1: 'o', 0: ' ', 1: 'x'}
        print(f"{shapes[self.board[0,0]]} | {shapes[self.board[0,1]]} | {shapes[self.board[0,2]]}")
        print('- + - + -')
        print(f"{shapes[self.board[1,0]]} | {shapes[self.board[1,1]]} | {shapes[self.board[1,2]]}")
        print('- + - + -')
        print(f"{shapes[self.board[2,0]]} | {shapes[self.board[2,1]]} | {shapes[self.board[2,2]]}")

# %% [markdown]
# ## 3.1. Create a benchmark
# We first create a benchmark by testing a random agent playing against Minimax AI

# %%
# TEST HOW GOOD RANDOM AI IS

ttt = TicTacToe()

x_ai = RandomAI(ttt)
ttt.x_ai = x_ai

o_ai = MinimaxAI(ttt)
ttt.o_ai = o_ai


counters = {-1:0, 0:0, 1:0}
n_games = int(1e4)

def run_trials():
    for i in range(n_games):
        if i % 50 == 0:
            print(i, "out of", n_games)
            print(f"stats: out of {i} games, x has won {counters[1]} times, o - {counters[-1]} times, and there were "
                  f"{counters[0]} draws.")

        ttt.reset()
        result = ttt.play_ai_game()
        if result < 0:
            result = -1
        elif result > 0:
            result = 1
        counters[result] += 1



run_trials()
# Out:
# 0 out of 10000
# stats: out of 0 games, x has won 0 times, o - 0 times, and there were 0 draws.
# 50 out of 10000
# stats: out of 50 games, x has won 0 times, o - 46 times, and there were 4 draws.
# 100 out of 10000
# stats: out of 100 games, x has won 3 times, o - 86 times, and there were 11 draws.
# 150 out of 10000
# stats: out of 150 games, x has won 6 times, o - 123 times, and there were 21 draws.
# 200 out of 10000
# stats: out of 200 games, x has won 7 times, o - 169 times, and there were 24 draws.
# 250 out of 10000
# stats: out of 250 games, x has won 9 times, o - 209 times, and there were 32 draws.
# 300 out of 10000
# stats: out of 300 games, x has won 12 times, o - 251 times, and there were 37 draws.
# 350 out of 10000
# stats: out of 350 games, x has won 13 times, o - 291 times, and there were 46 draws.
# 400 out of 10000
# stats: out of 400 games, x has won 13 times, o - 332 times, and there were 55 draws.
# 450 out of 10000
# stats: out of 450 games, x has won 17 times, o - 375 times, and there were 58 draws.
# 500 out of 10000
# stats: out of 500 games, x has won 21 times, o - 413 times, and there were 66 draws.
# 550 out of 10000
# stats: out of 550 games, x has won 23 times, o - 456 times, and there were 71 draws.
# 600 out of 10000
# stats: out of 600 games, x has won 26 times, o - 495 times, and there were 79 draws.
# 650 out of 10000
# stats: out of 650 games, x has won 27 times, o - 538 times, and there were 85 draws.
# 700 out of 10000
# stats: out of 700 games, x has won 28 times, o - 582 times, and there were 90 draws.
# 750 out of 10000
# stats: out of 750 games, x has won 30 times, o - 628 times, and there were 92 draws.
# 800 out of 10000
# stats: out of 800 games, x has won 30 times, o - 673 times, and there were 97 draws.
# 850 out of 10000
# stats: out of 850 games, x has won 30 times, o - 715 times, and there were 105 draws.
# 900 out of 10000
# stats: out of 900 games, x has won 30 times, o - 755 times, and there were 115 draws.
# 950 out of 10000
# stats: out of 950 games, x has won 31 times, o - 795 times, and there were 124 draws.
# 1000 out of 10000
# stats: out of 1000 games, x has won 32 times, o - 838 times, and there were 130 draws.
# 1050 out of 10000
# stats: out of 1050 games, x has won 33 times, o - 881 times, and there were 136 draws.
# 1100 out of 10000
# stats: out of 1100 games, x has won 33 times, o - 925 times, and there were 142 draws.
# 1150 out of 10000
# stats: out of 1150 games, x has won 35 times, o - 968 times, and there were 147 draws.
# 1200 out of 10000
# stats: out of 1200 games, x has won 36 times, o - 1015 times, and there were 149 draws.
# 1250 out of 10000
# stats: out of 1250 games, x has won 36 times, o - 1055 times, and there were 159 draws.
# 1300 out of 10000
# stats: out of 1300 games, x has won 37 times, o - 1098 times, and there were 165 draws.
# 1350 out of 10000
# stats: out of 1350 games, x has won 37 times, o - 1144 times, and there were 169 draws.
# 1400 out of 10000
# stats: out of 1400 games, x has won 38 times, o - 1190 times, and there were 172 draws.
# 1450 out of 10000
# stats: out of 1450 games, x has won 38 times, o - 1234 times, and there were 178 draws.
# 1500 out of 10000
# stats: out of 1500 games, x has won 40 times, o - 1278 times, and there were 182 draws.
# 1550 out of 10000
# stats: out of 1550 games, x has won 43 times, o - 1320 times, and there were 187 draws.
# 1600 out of 10000
# stats: out of 1600 games, x has won 44 times, o - 1364 times, and there were 192 draws.
# 1650 out of 10000
# stats: out of 1650 games, x has won 44 times, o - 1409 times, and there were 197 draws.
# 1700 out of 10000
# stats: out of 1700 games, x has won 44 times, o - 1448 times, and there were 208 draws.
# 1750 out of 10000
# stats: out of 1750 games, x has won 44 times, o - 1492 times, and there were 214 draws.
# 1800 out of 10000
# stats: out of 1800 games, x has won 47 times, o - 1533 times, and there were 220 draws.
# 1850 out of 10000
# stats: out of 1850 games, x has won 49 times, o - 1574 times, and there were 227 draws.
# 1900 out of 10000
# stats: out of 1900 games, x has won 49 times, o - 1619 times, and there were 232 draws.
# 1950 out of 10000
# stats: out of 1950 games, x has won 51 times, o - 1660 times, and there were 239 draws.
# 2000 out of 10000
# stats: out of 2000 games, x has won 54 times, o - 1700 times, and there were 246 draws.
# 2050 out of 10000
# stats: out of 2050 games, x has won 54 times, o - 1743 times, and there were 253 draws.
# 2100 out of 10000
# stats: out of 2100 games, x has won 55 times, o - 1789 times, and there were 256 draws.
# 2150 out of 10000
# stats: out of 2150 games, x has won 56 times, o - 1830 times, and there were 264 draws.
# 2200 out of 10000
# stats: out of 2200 games, x has won 56 times, o - 1875 times, and there were 269 draws.
# 2250 out of 10000
# stats: out of 2250 games, x has won 56 times, o - 1912 times, and there were 282 draws.
# 2300 out of 10000
# stats: out of 2300 games, x has won 58 times, o - 1953 times, and there were 289 draws.
# 2350 out of 10000
# stats: out of 2350 games, x has won 60 times, o - 1997 times, and there were 293 draws.
# 2400 out of 10000
# stats: out of 2400 games, x has won 61 times, o - 2041 times, and there were 298 draws.
# 2450 out of 10000
# stats: out of 2450 games, x has won 62 times, o - 2083 times, and there were 305 draws.
# 2500 out of 10000
# stats: out of 2500 games, x has won 64 times, o - 2129 times, and there were 307 draws.
# 2550 out of 10000
# stats: out of 2550 games, x has won 64 times, o - 2171 times, and there were 315 draws.
# 2600 out of 10000
# stats: out of 2600 games, x has won 66 times, o - 2214 times, and there were 320 draws.
# 2650 out of 10000
# stats: out of 2650 games, x has won 67 times, o - 2260 times, and there were 323 draws.
# 2700 out of 10000
# stats: out of 2700 games, x has won 67 times, o - 2304 times, and there were 329 draws.
# 2750 out of 10000
# stats: out of 2750 games, x has won 69 times, o - 2346 times, and there were 335 draws.
# 2800 out of 10000
# stats: out of 2800 games, x has won 70 times, o - 2389 times, and there were 341 draws.
# 2850 out of 10000
# stats: out of 2850 games, x has won 71 times, o - 2431 times, and there were 348 draws.
# 2900 out of 10000
# stats: out of 2900 games, x has won 72 times, o - 2474 times, and there were 354 draws.
# 2950 out of 10000
# stats: out of 2950 games, x has won 73 times, o - 2515 times, and there were 362 draws.
# 3000 out of 10000
# stats: out of 3000 games, x has won 73 times, o - 2560 times, and there were 367 draws.
# 3050 out of 10000
# stats: out of 3050 games, x has won 73 times, o - 2607 times, and there were 370 draws.
# 3100 out of 10000
# stats: out of 3100 games, x has won 73 times, o - 2648 times, and there were 379 draws.
# 3150 out of 10000
# stats: out of 3150 games, x has won 76 times, o - 2689 times, and there were 385 draws.
# 3200 out of 10000
# stats: out of 3200 games, x has won 77 times, o - 2726 times, and there were 397 draws.
# 3250 out of 10000
# stats: out of 3250 games, x has won 81 times, o - 2766 times, and there were 403 draws.
# 3300 out of 10000
# stats: out of 3300 games, x has won 84 times, o - 2807 times, and there were 409 draws.
# 3350 out of 10000
# stats: out of 3350 games, x has won 86 times, o - 2850 times, and there were 414 draws.
# 3400 out of 10000
# stats: out of 3400 games, x has won 86 times, o - 2895 times, and there were 419 draws.
# 3450 out of 10000
# stats: out of 3450 games, x has won 86 times, o - 2940 times, and there were 424 draws.
# 3500 out of 10000
# stats: out of 3500 games, x has won 87 times, o - 2981 times, and there were 432 draws.
# 3550 out of 10000
# stats: out of 3550 games, x has won 88 times, o - 3023 times, and there were 439 draws.
# 3600 out of 10000
# stats: out of 3600 games, x has won 89 times, o - 3063 times, and there were 448 draws.
# 3650 out of 10000
# stats: out of 3650 games, x has won 89 times, o - 3108 times, and there were 453 draws.
# 3700 out of 10000
# stats: out of 3700 games, x has won 91 times, o - 3152 times, and there were 457 draws.
# 3750 out of 10000
# stats: out of 3750 games, x has won 92 times, o - 3197 times, and there were 461 draws.
# 3800 out of 10000
# stats: out of 3800 games, x has won 93 times, o - 3239 times, and there were 468 draws.
# 3850 out of 10000
# stats: out of 3850 games, x has won 95 times, o - 3281 times, and there were 474 draws.
# 3900 out of 10000
# stats: out of 3900 games, x has won 96 times, o - 3327 times, and there were 477 draws.
# 3950 out of 10000
# stats: out of 3950 games, x has won 98 times, o - 3372 times, and there were 480 draws.
# 4000 out of 10000
# stats: out of 4000 games, x has won 101 times, o - 3416 times, and there were 483 draws.
# 4050 out of 10000
# stats: out of 4050 games, x has won 102 times, o - 3456 times, and there were 492 draws.
# 4100 out of 10000
# stats: out of 4100 games, x has won 103 times, o - 3498 times, and there were 499 draws.
# 4150 out of 10000
# stats: out of 4150 games, x has won 105 times, o - 3541 times, and there were 504 draws.
# 4200 out of 10000
# stats: out of 4200 games, x has won 107 times, o - 3584 times, and there were 509 draws.
# 4250 out of 10000
# stats: out of 4250 games, x has won 107 times, o - 3624 times, and there were 519 draws.
# 4300 out of 10000
# stats: out of 4300 games, x has won 108 times, o - 3668 times, and there were 524 draws.
# 4350 out of 10000
# stats: out of 4350 games, x has won 110 times, o - 3711 times, and there were 529 draws.
# 4400 out of 10000
# stats: out of 4400 games, x has won 112 times, o - 3754 times, and there were 534 draws.
# 4450 out of 10000
# stats: out of 4450 games, x has won 113 times, o - 3799 times, and there were 538 draws.
# 4500 out of 10000
# stats: out of 4500 games, x has won 119 times, o - 3838 times, and there were 543 draws.
# 4550 out of 10000
# stats: out of 4550 games, x has won 121 times, o - 3877 times, and there were 552 draws.
# 4600 out of 10000
# stats: out of 4600 games, x has won 123 times, o - 3918 times, and there were 559 draws.
# 4650 out of 10000
# stats: out of 4650 games, x has won 125 times, o - 3957 times, and there were 568 draws.
# 4700 out of 10000
# stats: out of 4700 games, x has won 125 times, o - 4000 times, and there were 575 draws.
# 4750 out of 10000
# stats: out of 4750 games, x has won 127 times, o - 4039 times, and there were 584 draws.
# 4800 out of 10000
# stats: out of 4800 games, x has won 128 times, o - 4082 times, and there were 590 draws.
# 4850 out of 10000
# stats: out of 4850 games, x has won 132 times, o - 4122 times, and there were 596 draws.
# 4900 out of 10000
# stats: out of 4900 games, x has won 133 times, o - 4165 times, and there were 602 draws.
# 4950 out of 10000
# stats: out of 4950 games, x has won 134 times, o - 4206 times, and there were 610 draws.
# 5000 out of 10000
# stats: out of 5000 games, x has won 137 times, o - 4245 times, and there were 618 draws.
# 5050 out of 10000
# stats: out of 5050 games, x has won 137 times, o - 4291 times, and there were 622 draws.
# 5100 out of 10000
# stats: out of 5100 games, x has won 137 times, o - 4332 times, and there were 631 draws.
# 5150 out of 10000
# stats: out of 5150 games, x has won 139 times, o - 4372 times, and there were 639 draws.
# 5200 out of 10000
# stats: out of 5200 games, x has won 140 times, o - 4417 times, and there were 643 draws.
# 5250 out of 10000
# stats: out of 5250 games, x has won 143 times, o - 4459 times, and there were 648 draws.
# 5300 out of 10000
# stats: out of 5300 games, x has won 143 times, o - 4502 times, and there were 655 draws.
# 5350 out of 10000
# stats: out of 5350 games, x has won 146 times, o - 4539 times, and there were 665 draws.
# 5400 out of 10000
# stats: out of 5400 games, x has won 150 times, o - 4577 times, and there were 673 draws.
# 5450 out of 10000
# stats: out of 5450 games, x has won 152 times, o - 4617 times, and there were 681 draws.
# 5500 out of 10000
# stats: out of 5500 games, x has won 156 times, o - 4655 times, and there were 689 draws.
# 5550 out of 10000
# stats: out of 5550 games, x has won 157 times, o - 4698 times, and there were 695 draws.
# 5600 out of 10000
# stats: out of 5600 games, x has won 157 times, o - 4740 times, and there were 703 draws.
# 5650 out of 10000
# stats: out of 5650 games, x has won 159 times, o - 4782 times, and there were 709 draws.
# 5700 out of 10000
# stats: out of 5700 games, x has won 159 times, o - 4825 times, and there were 716 draws.
# 5750 out of 10000
# stats: out of 5750 games, x has won 160 times, o - 4867 times, and there were 723 draws.
# 5800 out of 10000
# stats: out of 5800 games, x has won 162 times, o - 4911 times, and there were 727 draws.
# 5850 out of 10000
# stats: out of 5850 games, x has won 164 times, o - 4950 times, and there were 736 draws.
# 5900 out of 10000
# stats: out of 5900 games, x has won 165 times, o - 4993 times, and there were 742 draws.
# 5950 out of 10000
# stats: out of 5950 games, x has won 167 times, o - 5037 times, and there were 746 draws.
# 6000 out of 10000
# stats: out of 6000 games, x has won 168 times, o - 5080 times, and there were 752 draws.
# 6050 out of 10000
# stats: out of 6050 games, x has won 169 times, o - 5124 times, and there were 757 draws.
# 6100 out of 10000
# stats: out of 6100 games, x has won 171 times, o - 5163 times, and there were 766 draws.
# 6150 out of 10000
# stats: out of 6150 games, x has won 171 times, o - 5205 times, and there were 774 draws.
# 6200 out of 10000
# stats: out of 6200 games, x has won 174 times, o - 5247 times, and there were 779 draws.
# 6250 out of 10000
# stats: out of 6250 games, x has won 175 times, o - 5287 times, and there were 788 draws.
# 6300 out of 10000
# stats: out of 6300 games, x has won 175 times, o - 5331 times, and there were 794 draws.
# 6350 out of 10000
# stats: out of 6350 games, x has won 176 times, o - 5370 times, and there were 804 draws.
# 6400 out of 10000
# stats: out of 6400 games, x has won 177 times, o - 5413 times, and there were 810 draws.
# 6450 out of 10000
# stats: out of 6450 games, x has won 177 times, o - 5455 times, and there were 818 draws.
# 6500 out of 10000
# stats: out of 6500 games, x has won 177 times, o - 5498 times, and there were 825 draws.
# 6550 out of 10000
# stats: out of 6550 games, x has won 177 times, o - 5541 times, and there were 832 draws.
# 6600 out of 10000
# stats: out of 6600 games, x has won 179 times, o - 5584 times, and there were 837 draws.
# 6650 out of 10000
# stats: out of 6650 games, x has won 181 times, o - 5624 times, and there were 845 draws.
# 6700 out of 10000
# stats: out of 6700 games, x has won 181 times, o - 5666 times, and there were 853 draws.
# 6750 out of 10000
# stats: out of 6750 games, x has won 183 times, o - 5708 times, and there were 859 draws.
# 6800 out of 10000
# stats: out of 6800 games, x has won 187 times, o - 5746 times, and there were 867 draws.
# 6850 out of 10000
# stats: out of 6850 games, x has won 188 times, o - 5791 times, and there were 871 draws.
# 6900 out of 10000
# stats: out of 6900 games, x has won 190 times, o - 5833 times, and there were 877 draws.
# 6950 out of 10000
# stats: out of 6950 games, x has won 193 times, o - 5873 times, and there were 884 draws.
# 7000 out of 10000
# stats: out of 7000 games, x has won 195 times, o - 5915 times, and there were 890 draws.
# 7050 out of 10000
# stats: out of 7050 games, x has won 195 times, o - 5959 times, and there were 896 draws.
# 7100 out of 10000
# stats: out of 7100 games, x has won 197 times, o - 5996 times, and there were 907 draws.
# 7150 out of 10000
# stats: out of 7150 games, x has won 198 times, o - 6041 times, and there were 911 draws.
# 7200 out of 10000
# stats: out of 7200 games, x has won 198 times, o - 6087 times, and there were 915 draws.
# 7250 out of 10000
# stats: out of 7250 games, x has won 200 times, o - 6132 times, and there were 918 draws.
# 7300 out of 10000
# stats: out of 7300 games, x has won 202 times, o - 6169 times, and there were 929 draws.
# 7350 out of 10000
# stats: out of 7350 games, x has won 205 times, o - 6213 times, and there were 932 draws.
# 7400 out of 10000
# stats: out of 7400 games, x has won 207 times, o - 6258 times, and there were 935 draws.
# 7450 out of 10000
# stats: out of 7450 games, x has won 209 times, o - 6301 times, and there were 940 draws.
# 7500 out of 10000
# stats: out of 7500 games, x has won 210 times, o - 6344 times, and there were 946 draws.
# 7550 out of 10000
# stats: out of 7550 games, x has won 211 times, o - 6388 times, and there were 951 draws.
# 7600 out of 10000
# stats: out of 7600 games, x has won 214 times, o - 6426 times, and there were 960 draws.
# 7650 out of 10000
# stats: out of 7650 games, x has won 215 times, o - 6473 times, and there were 962 draws.
# 7700 out of 10000
# stats: out of 7700 games, x has won 216 times, o - 6513 times, and there were 971 draws.
# 7750 out of 10000
# stats: out of 7750 games, x has won 217 times, o - 6559 times, and there were 974 draws.
# 7800 out of 10000
# stats: out of 7800 games, x has won 217 times, o - 6601 times, and there were 982 draws.
# 7850 out of 10000
# stats: out of 7850 games, x has won 218 times, o - 6646 times, and there were 986 draws.
# 7900 out of 10000
# stats: out of 7900 games, x has won 219 times, o - 6690 times, and there were 991 draws.
# 7950 out of 10000
# stats: out of 7950 games, x has won 221 times, o - 6731 times, and there were 998 draws.
# 8000 out of 10000
# stats: out of 8000 games, x has won 222 times, o - 6775 times, and there were 1003 draws.
# 8050 out of 10000
# stats: out of 8050 games, x has won 222 times, o - 6818 times, and there were 1010 draws.
# 8100 out of 10000
# stats: out of 8100 games, x has won 224 times, o - 6861 times, and there were 1015 draws.
# 8150 out of 10000
# stats: out of 8150 games, x has won 226 times, o - 6901 times, and there were 1023 draws.
# 8200 out of 10000
# stats: out of 8200 games, x has won 230 times, o - 6944 times, and there were 1026 draws.
# 8250 out of 10000
# stats: out of 8250 games, x has won 232 times, o - 6981 times, and there were 1037 draws.
# 8300 out of 10000
# stats: out of 8300 games, x has won 234 times, o - 7021 times, and there were 1045 draws.
# 8350 out of 10000
# stats: out of 8350 games, x has won 236 times, o - 7059 times, and there were 1055 draws.
# 8400 out of 10000
# stats: out of 8400 games, x has won 238 times, o - 7101 times, and there were 1061 draws.
# 8450 out of 10000
# stats: out of 8450 games, x has won 239 times, o - 7145 times, and there were 1066 draws.
# 8500 out of 10000
# stats: out of 8500 games, x has won 240 times, o - 7185 times, and there were 1075 draws.
# 8550 out of 10000
# stats: out of 8550 games, x has won 242 times, o - 7223 times, and there were 1085 draws.
# 8600 out of 10000
# stats: out of 8600 games, x has won 242 times, o - 7263 times, and there were 1095 draws.
# 8650 out of 10000
# stats: out of 8650 games, x has won 243 times, o - 7306 times, and there were 1101 draws.
# 8700 out of 10000
# stats: out of 8700 games, x has won 243 times, o - 7351 times, and there were 1106 draws.
# 8750 out of 10000
# stats: out of 8750 games, x has won 244 times, o - 7389 times, and there were 1117 draws.
# 8800 out of 10000
# stats: out of 8800 games, x has won 244 times, o - 7430 times, and there were 1126 draws.
# 8850 out of 10000
# stats: out of 8850 games, x has won 246 times, o - 7470 times, and there were 1134 draws.
# 8900 out of 10000
# stats: out of 8900 games, x has won 246 times, o - 7511 times, and there were 1143 draws.
# 8950 out of 10000
# stats: out of 8950 games, x has won 246 times, o - 7554 times, and there were 1150 draws.
# 9000 out of 10000
# stats: out of 9000 games, x has won 246 times, o - 7598 times, and there were 1156 draws.
# 9050 out of 10000
# stats: out of 9050 games, x has won 248 times, o - 7637 times, and there were 1165 draws.
# 9100 out of 10000
# stats: out of 9100 games, x has won 249 times, o - 7680 times, and there were 1171 draws.
# 9150 out of 10000
# stats: out of 9150 games, x has won 250 times, o - 7720 times, and there were 1180 draws.
# 9200 out of 10000
# stats: out of 9200 games, x has won 251 times, o - 7764 times, and there were 1185 draws.
# 9250 out of 10000
# stats: out of 9250 games, x has won 253 times, o - 7802 times, and there were 1195 draws.
# 9300 out of 10000
# stats: out of 9300 games, x has won 253 times, o - 7842 times, and there were 1205 draws.
# 9350 out of 10000
# stats: out of 9350 games, x has won 255 times, o - 7885 times, and there were 1210 draws.
# 9400 out of 10000
# stats: out of 9400 games, x has won 255 times, o - 7931 times, and there were 1214 draws.
# 9450 out of 10000
# stats: out of 9450 games, x has won 256 times, o - 7977 times, and there were 1217 draws.
# 9500 out of 10000
# stats: out of 9500 games, x has won 257 times, o - 8021 times, and there were 1222 draws.
# 9550 out of 10000
# stats: out of 9550 games, x has won 258 times, o - 8068 times, and there were 1224 draws.
# 9600 out of 10000
# stats: out of 9600 games, x has won 259 times, o - 8113 times, and there were 1228 draws.
# 9650 out of 10000
# stats: out of 9650 games, x has won 259 times, o - 8154 times, and there were 1237 draws.
# 9700 out of 10000
# stats: out of 9700 games, x has won 261 times, o - 8197 times, and there were 1242 draws.
# 9750 out of 10000
# stats: out of 9750 games, x has won 261 times, o - 8243 times, and there were 1246 draws.
# 9800 out of 10000
# stats: out of 9800 games, x has won 262 times, o - 8287 times, and there were 1251 draws.
# 9850 out of 10000
# stats: out of 9850 games, x has won 265 times, o - 8326 times, and there were 1259 draws.
# 9900 out of 10000
# stats: out of 9900 games, x has won 267 times, o - 8367 times, and there were 1266 draws.
# 9950 out of 10000
# stats: out of 9950 games, x has won 267 times, o - 8410 times, and there were 1273 draws.

# %% [markdown]
# ## 3.2. Train the reinforcement learning agent
# Next, we train a neural network to play against Minimax AI

# %%
# TRAIN DQN FOR TIC-TAC-TOE

from __future__ import division
import argparse

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.callbacks import FileLogger, ModelIntervalCheckpoint



# Get the environment and extract the number of actions.
from gym.wrappers import TimeLimit
env = TimeLimit(TicTacToe(), max_episode_steps=10)
nb_actions = env.action_space.n

# Next, we build our model. We use the same model that was described by Mnih et al. (2015).
WINDOW_LENGTH = 4
input_shape = (3,3)
input_shape = (WINDOW_LENGTH,) + input_shape

def build_model():
    model = Sequential()
    model.add(Flatten(input_shape=input_shape))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(nb_actions))
    print(model.summary())
    return model


model = build_model()

# Finally, we configure and compile our agent. You can use every built-in Keras optimizer and
# even the metrics!
memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

# Select a policy. We use eps-greedy action selection, which means that a random action is selected
# with probability eps. We anneal eps from 1.0 to 0.1 over the course of 1M steps. This is done so that
# the agent initially explores the environment (high eps) and then gradually sticks to what it knows
# (low eps). We also set a dedicated eps value that is used during testing. Note that we set it to 0.05
# so that the agent still performs some random actions. This ensures that the agent cannot get stuck.
policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps', value_max=1., value_min=.1, value_test=.05,
                              nb_steps=300000)

# The trade-off between exploration and exploitation is difficult and an on-going research topic.
# If you want, you can experiment with the parameters or use a different policy. Another popular one
# is Boltzmann-style exploration:
# policy = BoltzmannQPolicy(tau=1.)
# Feel free to give it a try!
dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy, memory=memory, nb_steps_warmup=50000, gamma=.99,
               target_model_update=10000,
               train_interval=4, delta_clip=1.)
dqn.compile(Adam(lr=1e-3), metrics=['mae'])

print("about to enter the flags branching.")


# Okay, now it's time to learn something! We capture the interrupt exception so that training
# can be prematurely aborted. Notice that you can the built-in Keras callbacks!
weights_filename = 'dqn_ttt_weights.h5f'
checkpoint_weights_filename = 'dqn_ttt_weights_{step}.h5f'
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=50000)]
print("about to fit the dqn!")
# dqn.load_weights(weights_filename)
dqn.fit(env, callbacks=callbacks, nb_steps=int(4e5), log_interval=10000, verbose=1)

# After training is done, we save the final weights one more time.
dqn.save_weights(weights_filename, overwrite=True)

# Finally, evaluate our algorithm for 10 episodes.
dqn.test(env, nb_episodes=1, visualize=False)
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 36)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1184
# _________________________________________________________________
# dense_2 (Dense)              (None, 9)                 297
# =================================================================
# Total params: 1,481
# Trainable params: 1,481
# Non-trainable params: 0
# _________________________________________________________________
# None
# about to enter the flags branching.
# about to fit the dqn!
# Training for 1000000 steps ...
# Interval 1 (0 steps performed)
# 10000/10000 [==============================] - 43s 4ms/step - reward: -0.4992
# 3821 episodes - episode_reward: -1.306 [-1.500, 0.930]
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 43s 4ms/step - reward: -0.4973
# 3815 episodes - episode_reward: -1.304 [-1.500, 0.930]
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 44s 4ms/step - reward: -0.4991
# 3797 episodes - episode_reward: -1.315 [-1.500, 0.930]
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 43s 4ms/step - reward: -0.4977
# 3822 episodes - episode_reward: -1.302 [-1.500, 0.930]
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 43s 4ms/step - reward: -0.5002
# 3839 episodes - episode_reward: -1.303 [-1.500, 0.930]
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 68s 7ms/step - reward: -0.4941
# 3787 episodes - episode_reward: -1.305 [-1.500, 0.930] - loss: 0.104 - mean_absolute_error: 0.543 - mean_q: -0.198 - mean_eps: 0.951
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -0.4878
# 3755 episodes - episode_reward: -1.299 [-1.500, 0.930] - loss: 0.017 - mean_absolute_error: 0.710 - mean_q: -0.450 - mean_eps: 0.942
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -0.4781
# 3699 episodes - episode_reward: -1.292 [-1.500, 0.930] - loss: 0.007 - mean_absolute_error: 0.796 - mean_q: -0.603 - mean_eps: 0.933
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -0.4780
# 3704 episodes - episode_reward: -1.290 [-1.500, 0.930] - loss: 0.006 - mean_absolute_error: 0.833 - mean_q: -0.671 - mean_eps: 0.924
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -0.4764
# 3707 episodes - episode_reward: -1.285 [-1.500, 0.930] - loss: 0.005 - mean_absolute_error: 0.864 - mean_q: -0.720 - mean_eps: 0.915
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -0.4714
# 3660 episodes - episode_reward: -1.288 [-1.500, 0.930] - loss: 0.005 - mean_absolute_error: 0.877 - mean_q: -0.731 - mean_eps: 0.906
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 67s 7ms/step - reward: -0.4708
# 3672 episodes - episode_reward: -1.282 [-1.500, 0.930] - loss: 0.005 - mean_absolute_error: 0.878 - mean_q: -0.723 - mean_eps: 0.897
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -0.4739
# 3702 episodes - episode_reward: -1.280 [-1.500, 0.930] - loss: 0.005 - mean_absolute_error: 0.863 - mean_q: -0.702 - mean_eps: 0.888
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -0.4565
# 3608 episodes - episode_reward: -1.265 [-1.500, 0.930] - loss: 0.005 - mean_absolute_error: 0.857 - mean_q: -0.682 - mean_eps: 0.879
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -0.4708
# 3644 episodes - episode_reward: -1.292 [-1.500, 0.930] - loss: 0.006 - mean_absolute_error: 0.848 - mean_q: -0.663 - mean_eps: 0.870
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -0.4659
# 3642 episodes - episode_reward: -1.279 [-1.500, 0.930] - loss: 0.006 - mean_absolute_error: 0.837 - mean_q: -0.639 - mean_eps: 0.861
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -0.4616
# 3606 episodes - episode_reward: -1.280 [-1.500, 0.930] - loss: 0.006 - mean_absolute_error: 0.829 - mean_q: -0.626 - mean_eps: 0.852
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 65s 7ms/step - reward: -0.4543
# 3621 episodes - episode_reward: -1.255 [-1.500, 0.930] - loss: 0.007 - mean_absolute_error: 0.819 - mean_q: -0.607 - mean_eps: 0.843
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -0.4566
# 3567 episodes - episode_reward: -1.280 [-1.500, 0.930] - loss: 0.007 - mean_absolute_error: 0.809 - mean_q: -0.588 - mean_eps: 0.834
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -0.4504
# 3563 episodes - episode_reward: -1.264 [-1.500, 0.930] - loss: 0.008 - mean_absolute_error: 0.798 - mean_q: -0.554 - mean_eps: 0.825
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - ETA: 0s - reward: -0.45 - 65s 7ms/step - reward: -0.4518
# 3583 episodes - episode_reward: -1.261 [-1.500, 0.930] - loss: 0.009 - mean_absolute_error: 0.789 - mean_q: -0.532 - mean_eps: 0.816
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -0.4460
# 3531 episodes - episode_reward: -1.263 [-1.500, 0.930] - loss: 0.009 - mean_absolute_error: 0.771 - mean_q: -0.499 - mean_eps: 0.807
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -0.4408
# 3515 episodes - episode_reward: -1.254 [-1.500, 0.930] - loss: 0.011 - mean_absolute_error: 0.762 - mean_q: -0.469 - mean_eps: 0.798
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 66s 7ms/step - reward: -0.4352
# 3502 episodes - episode_reward: -1.243 [-1.500, 0.930] - loss: 0.011 - mean_absolute_error: 0.753 - mean_q: -0.440 - mean_eps: 0.789
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 65s 6ms/step - reward: -0.4306
# 3469 episodes - episode_reward: -1.241 [-1.500, 0.930] - loss: 0.012 - mean_absolute_error: 0.743 - mean_q: -0.433 - mean_eps: 0.780
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 65s 7ms/step - reward: -0.4332
# 3470 episodes - episode_reward: -1.248 [-1.500, 0.930] - loss: 0.011 - mean_absolute_error: 0.730 - mean_q: -0.411 - mean_eps: 0.771
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 65s 6ms/step - reward: -0.4201
# 3450 episodes - episode_reward: -1.218 [-1.500, 0.930] - loss: 0.013 - mean_absolute_error: 0.723 - mean_q: -0.388 - mean_eps: 0.762
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 65s 7ms/step - reward: -0.4214
# 3432 episodes - episode_reward: -1.228 [-1.500, 0.930] - loss: 0.014 - mean_absolute_error: 0.708 - mean_q: -0.346 - mean_eps: 0.753
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 65s 7ms/step - reward: -0.4226
# 3428 episodes - episode_reward: -1.233 [-1.500, 0.930] - loss: 0.014 - mean_absolute_error: 0.702 - mean_q: -0.328 - mean_eps: 0.744
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 65s 6ms/step - reward: -0.4158
# 3400 episodes - episode_reward: -1.223 [-1.500, 0.930] - loss: 0.015 - mean_absolute_error: 0.693 - mean_q: -0.317 - mean_eps: 0.735
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 65s 7ms/step - reward: -0.4081
# 3388 episodes - episode_reward: -1.205 [-1.500, 0.930] - loss: 0.015 - mean_absolute_error: 0.683 - mean_q: -0.290 - mean_eps: 0.726
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 65s 6ms/step - reward: -0.4117
# 3397 episodes - episode_reward: -1.212 [-1.500, 0.930] - loss: 0.015 - mean_absolute_error: 0.684 - mean_q: -0.281 - mean_eps: 0.717
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.4060
# 3380 episodes - episode_reward: -1.201 [-1.500, 0.930] - loss: 0.016 - mean_absolute_error: 0.683 - mean_q: -0.283 - mean_eps: 0.708
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3999
# 3351 episodes - episode_reward: -1.193 [-1.500, 0.930] - loss: 0.017 - mean_absolute_error: 0.678 - mean_q: -0.256 - mean_eps: 0.699
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 65s 6ms/step - reward: -0.3999
# 3363 episodes - episode_reward: -1.189 [-1.500, 0.930] - loss: 0.017 - mean_absolute_error: 0.672 - mean_q: -0.235 - mean_eps: 0.690
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3950
# 3328 episodes - episode_reward: -1.187 [-1.500, 0.930] - loss: 0.017 - mean_absolute_error: 0.672 - mean_q: -0.229 - mean_eps: 0.681
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3876
# 3304 episodes - episode_reward: -1.173 [-1.500, 0.930] - loss: 0.018 - mean_absolute_error: 0.651 - mean_q: -0.176 - mean_eps: 0.672
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.3834
# 3298 episodes - episode_reward: -1.163 [-1.500, 0.930] - loss: 0.020 - mean_absolute_error: 0.648 - mean_q: -0.158 - mean_eps: 0.663
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3759
# 3276 episodes - episode_reward: -1.147 [-1.500, 0.930] - loss: 0.021 - mean_absolute_error: 0.647 - mean_q: -0.134 - mean_eps: 0.654
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3719
# 3276 episodes - episode_reward: -1.135 [-1.500, 0.930] - loss: 0.022 - mean_absolute_error: 0.649 - mean_q: -0.141 - mean_eps: 0.645
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 65s 6ms/step - reward: -0.3592
# 3221 episodes - episode_reward: -1.115 [-1.500, 0.930] - loss: 0.021 - mean_absolute_error: 0.659 - mean_q: -0.130 - mean_eps: 0.636
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3658
# 3267 episodes - episode_reward: -1.120 [-1.500, 0.930] - loss: 0.021 - mean_absolute_error: 0.653 - mean_q: -0.127 - mean_eps: 0.627
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3721
# 3256 episodes - episode_reward: -1.143 [-1.500, 0.930] - loss: 0.022 - mean_absolute_error: 0.651 - mean_q: -0.111 - mean_eps: 0.618
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3630
# 3273 episodes - episode_reward: -1.109 [-1.500, 0.930] - loss: 0.024 - mean_absolute_error: 0.645 - mean_q: -0.065 - mean_eps: 0.609
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3492
# 3180 episodes - episode_reward: -1.098 [-1.500, 0.930] - loss: 0.025 - mean_absolute_error: 0.651 - mean_q: -0.062 - mean_eps: 0.600
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3432
# 3192 episodes - episode_reward: -1.075 [-1.500, 0.930] - loss: 0.024 - mean_absolute_error: 0.648 - mean_q: -0.073 - mean_eps: 0.591
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3428
# 3187 episodes - episode_reward: -1.075 [-1.500, 0.930] - loss: 0.024 - mean_absolute_error: 0.653 - mean_q: -0.081 - mean_eps: 0.582
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.3311
# 3158 episodes - episode_reward: -1.049 [-1.500, 0.930] - loss: 0.022 - mean_absolute_error: 0.661 - mean_q: -0.091 - mean_eps: 0.573
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.3310
# 3138 episodes - episode_reward: -1.055 [-1.500, 0.930] - loss: 0.023 - mean_absolute_error: 0.658 - mean_q: -0.088 - mean_eps: 0.564
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.3238
# 3159 episodes - episode_reward: -1.025 [-1.500, 0.930] - loss: 0.023 - mean_absolute_error: 0.653 - mean_q: -0.068 - mean_eps: 0.555
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3289
# 3141 episodes - episode_reward: -1.047 [-1.500, 0.930] - loss: 0.024 - mean_absolute_error: 0.657 - mean_q: -0.071 - mean_eps: 0.546
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.3284
# 3160 episodes - episode_reward: -1.039 [-1.500, 0.930] - loss: 0.024 - mean_absolute_error: 0.655 - mean_q: -0.052 - mean_eps: 0.537
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.3119
# 3104 episodes - episode_reward: -1.005 [-1.500, 0.930] - loss: 0.026 - mean_absolute_error: 0.659 - mean_q: -0.035 - mean_eps: 0.528
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 64s 6ms/step - reward: -0.2998
# 3071 episodes - episode_reward: -0.976 [-1.500, 0.930] - loss: 0.027 - mean_absolute_error: 0.658 - mean_q: -0.014 - mean_eps: 0.519
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.3079
# 3091 episodes - episode_reward: -0.996 [-1.500, 0.930] - loss: 0.027 - mean_absolute_error: 0.666 - mean_q: -0.023 - mean_eps: 0.510
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.2994
# 3097 episodes - episode_reward: -0.967 [-1.500, 0.930] - loss: 0.026 - mean_absolute_error: 0.665 - mean_q: -0.031 - mean_eps: 0.501
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.2942
# 3067 episodes - episode_reward: -0.959 [-1.500, 0.930] - loss: 0.025 - mean_absolute_error: 0.669 - mean_q: -0.018 - mean_eps: 0.492
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.2895
# 3040 episodes - episode_reward: -0.952 [-1.500, 0.930] - loss: 0.026 - mean_absolute_error: 0.658 - mean_q: 0.005 - mean_eps: 0.483
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.2894
# 3067 episodes - episode_reward: -0.943 [-1.500, 0.930] - loss: 0.026 - mean_absolute_error: 0.663 - mean_q: 0.011 - mean_eps: 0.474
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.2693
# 3017 episodes - episode_reward: -0.892 [-1.500, 0.930] - loss: 0.028 - mean_absolute_error: 0.663 - mean_q: 0.027 - mean_eps: 0.465
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.2760
# 3028 episodes - episode_reward: -0.911 [-1.500, 0.930] - loss: 0.028 - mean_absolute_error: 0.659 - mean_q: 0.032 - mean_eps: 0.456
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.2717
# 3009 episodes - episode_reward: -0.903 [-1.500, 0.930] - loss: 0.028 - mean_absolute_error: 0.661 - mean_q: 0.046 - mean_eps: 0.447
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.2603
# 2996 episodes - episode_reward: -0.869 [-1.500, 0.930] - loss: 0.029 - mean_absolute_error: 0.662 - mean_q: 0.065 - mean_eps: 0.438
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.2609
# 3000 episodes - episode_reward: -0.870 [-1.500, 0.930] - loss: 0.028 - mean_absolute_error: 0.669 - mean_q: 0.054 - mean_eps: 0.429
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.2501
# 2978 episodes - episode_reward: -0.840 [-1.500, 0.930] - loss: 0.028 - mean_absolute_error: 0.669 - mean_q: 0.048 - mean_eps: 0.420
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.2450
# 2978 episodes - episode_reward: -0.823 [-1.500, 0.930] - loss: 0.027 - mean_absolute_error: 0.673 - mean_q: 0.030 - mean_eps: 0.411
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.2395
# 2991 episodes - episode_reward: -0.801 [-1.500, 0.930] - loss: 0.030 - mean_absolute_error: 0.677 - mean_q: 0.059 - mean_eps: 0.402
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.2281
# 2937 episodes - episode_reward: -0.777 [-1.500, 0.930] - loss: 0.030 - mean_absolute_error: 0.675 - mean_q: 0.056 - mean_eps: 0.393
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.2279
# 2957 episodes - episode_reward: -0.771 [-1.500, 0.930] - loss: 0.028 - mean_absolute_error: 0.668 - mean_q: 0.086 - mean_eps: 0.384
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.2198
# 2917 episodes - episode_reward: -0.753 [-1.500, 0.930] - loss: 0.030 - mean_absolute_error: 0.670 - mean_q: 0.108 - mean_eps: 0.375
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.2150
# 2926 episodes - episode_reward: -0.735 [-1.500, 0.930] - loss: 0.030 - mean_absolute_error: 0.675 - mean_q: 0.069 - mean_eps: 0.366
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.2141
# 2907 episodes - episode_reward: -0.737 [-1.500, 0.930] - loss: 0.029 - mean_absolute_error: 0.674 - mean_q: 0.082 - mean_eps: 0.357
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.1952
# 2893 episodes - episode_reward: -0.675 [-1.500, 0.930] - loss: 0.029 - mean_absolute_error: 0.666 - mean_q: 0.090 - mean_eps: 0.348
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.1886
# 2894 episodes - episode_reward: -0.652 [-1.500, 0.930] - loss: 0.031 - mean_absolute_error: 0.665 - mean_q: 0.109 - mean_eps: 0.339
#
# Interval 75 (740000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.1912
# 2881 episodes - episode_reward: -0.664 [-1.500, 0.930] - loss: 0.031 - mean_absolute_error: 0.667 - mean_q: 0.124 - mean_eps: 0.330
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 63s 6ms/step - reward: -0.1828
# 2869 episodes - episode_reward: -0.637 [-1.500, 0.930] - loss: 0.032 - mean_absolute_error: 0.666 - mean_q: 0.143 - mean_eps: 0.321
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.1710
# 2867 episodes - episode_reward: -0.597 [-1.500, 0.930] - loss: 0.034 - mean_absolute_error: 0.670 - mean_q: 0.155 - mean_eps: 0.312
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.1650
# 2868 episodes - episode_reward: -0.575 [-1.500, 0.930] - loss: 0.033 - mean_absolute_error: 0.673 - mean_q: 0.159 - mean_eps: 0.303
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.1631
# 2843 episodes - episode_reward: -0.574 [-1.500, 0.930] - loss: 0.032 - mean_absolute_error: 0.675 - mean_q: 0.157 - mean_eps: 0.294
#
# Interval 80 (790000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.1577
# 2830 episodes - episode_reward: -0.557 [-1.500, 0.930] - loss: 0.032 - mean_absolute_error: 0.678 - mean_q: 0.162 - mean_eps: 0.285
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.1577
# 2841 episodes - episode_reward: -0.555 [-1.500, 0.930] - loss: 0.032 - mean_absolute_error: 0.684 - mean_q: 0.152 - mean_eps: 0.276
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.1343
# 2787 episodes - episode_reward: -0.482 [-1.500, 0.930] - loss: 0.033 - mean_absolute_error: 0.675 - mean_q: 0.164 - mean_eps: 0.267
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.1318
# 2817 episodes - episode_reward: -0.468 [-1.500, 0.930] - loss: 0.031 - mean_absolute_error: 0.680 - mean_q: 0.168 - mean_eps: 0.258
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.1327
# 2807 episodes - episode_reward: -0.473 [-1.500, 0.930] - loss: 0.032 - mean_absolute_error: 0.688 - mean_q: 0.169 - mean_eps: 0.249
#
# Interval 85 (840000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.1193
# 2797 episodes - episode_reward: -0.427 [-1.500, 0.930] - loss: 0.034 - mean_absolute_error: 0.687 - mean_q: 0.165 - mean_eps: 0.240
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.0954
# 2766 episodes - episode_reward: -0.345 [-1.500, 0.930] - loss: 0.033 - mean_absolute_error: 0.688 - mean_q: 0.166 - mean_eps: 0.231
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.0955
# 2783 episodes - episode_reward: -0.343 [-1.500, 0.930] - loss: 0.033 - mean_absolute_error: 0.691 - mean_q: 0.163 - mean_eps: 0.222
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.0995
# 2767 episodes - episode_reward: -0.360 [-1.500, 0.930] - loss: 0.034 - mean_absolute_error: 0.691 - mean_q: 0.184 - mean_eps: 0.213
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 62s 6ms/step - reward: -0.0816
# 2746 episodes - episode_reward: -0.297 [-1.500, 0.930] - loss: 0.035 - mean_absolute_error: 0.697 - mean_q: 0.188 - mean_eps: 0.204
#
# Interval 90 (890000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.0734
# 2728 episodes - episode_reward: -0.269 [-1.500, 0.930] - loss: 0.032 - mean_absolute_error: 0.692 - mean_q: 0.167 - mean_eps: 0.195
#
# Interval 91 (900000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.0754
# 2735 episodes - episode_reward: -0.276 [-1.500, 0.930] - loss: 0.031 - mean_absolute_error: 0.693 - mean_q: 0.169 - mean_eps: 0.186
#
# Interval 92 (910000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.0618
# 2721 episodes - episode_reward: -0.227 [-1.500, 0.930] - loss: 0.034 - mean_absolute_error: 0.700 - mean_q: 0.182 - mean_eps: 0.177
#
# Interval 93 (920000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -0.0512
# 2676 episodes - episode_reward: -0.191 [-1.500, 0.930] - loss: 0.032 - mean_absolute_error: 0.696 - mean_q: 0.184 - mean_eps: 0.168
#
# Interval 94 (930000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -0.0492
# 2720 episodes - episode_reward: -0.181 [-1.500, 0.930] - loss: 0.033 - mean_absolute_error: 0.697 - mean_q: 0.211 - mean_eps: 0.159
#
# Interval 95 (940000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.0332
# 2686 episodes - episode_reward: -0.124 [-1.500, 0.930] - loss: 0.034 - mean_absolute_error: 0.703 - mean_q: 0.218 - mean_eps: 0.150
#
# Interval 96 (950000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -0.0274
# 2675 episodes - episode_reward: -0.103 [-1.500, 0.930] - loss: 0.034 - mean_absolute_error: 0.706 - mean_q: 0.204 - mean_eps: 0.141
#
# Interval 97 (960000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: -0.0208
# 2682 episodes - episode_reward: -0.077 [-1.500, 0.930] - loss: 0.034 - mean_absolute_error: 0.705 - mean_q: 0.212 - mean_eps: 0.132
#
# Interval 98 (970000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: -0.0197
# 2683 episodes - episode_reward: -0.074 [-1.500, 0.930] - loss: 0.033 - mean_absolute_error: 0.705 - mean_q: 0.240 - mean_eps: 0.123
#
# Interval 99 (980000 steps performed)
# 10000/10000 [==============================] - 61s 6ms/step - reward: 5.0400e-04
# 2642 episodes - episode_reward: 0.002 [-1.500, 0.930] - loss: 0.035 - mean_absolute_error: 0.708 - mean_q: 0.238 - mean_eps: 0.114
#
# Interval 100 (990000 steps performed)
# 10000/10000 [==============================] - 60s 6ms/step - reward: 0.0060
# done, took 6238.357 seconds
# Testing for 1 episodes ...
# Episode 1: reward: 0.000, steps: 4

# %% [markdown]
# ## 3.3. Reinforcement Learning agent class to use the same API as other AIs
# NeuralAI class - an agent API using the neural network we have trained.

# %%
# DEFINE AGENT BASED ON THE DQN NET

from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import Adam
from rl.memory import SequentialMemory
from rl.agents.dqn import DQNAgent


WINDOW_LENGTH = 4
input_shape = (3, 3)
input_shape = (WINDOW_LENGTH,) + input_shape
nb_actions = 9


class NeuralAI:

    def __init__(self, game, weights_path=None):
        self.game = game
        model = self.build_model()
        dqn = DQNAgent(model=model, nb_actions=nb_actions, gamma=.99,
                       memory=SequentialMemory(limit=10, window_length=WINDOW_LENGTH))

        dqn.compile(Adam(lr=1e-3), metrics=['mae'])
        import sys
        sys.path.append("../")
        weights_filename = weights_path or 'dqn_ttt_weights.h5f'
        dqn.load_weights(weights_filename)
        self.dqn = dqn

    def decide_turn(self):
        board = self.game.board
        action = self.dqn.forward(board)
        row = action // 3
        column = action % 3

        return row, column

    @staticmethod
    def build_model():
        model = Sequential()
        model.add(Flatten(input_shape=input_shape))
        model.add(Dense(32, activation='relu'))
        model.add(Dense(nb_actions))
        return model

# %% [markdown]
# ## 3.4. Benchmark the trained agent
#
# The network is trained now. We benchmark it to compare it with random AI and Minimax AI; we also analyse how much computation do Minimax and the neural network agent require.

# %%
# TEST THE NEURAL AI

ttt = TicTacToe()

x_ai = NeuralAI(ttt)
ttt.x_ai = x_ai

o_ai = MinimaxAI(ttt)
ttt.o_ai = o_ai


counters = {-1:0, 0:0, 1:0}
n_games = int(1e4)

def run_trials():
    for i in range(n_games):
        if i % 50 == 0:
            print(i, "out of", n_games)
            print(f"stats: out of {i} games, x has won {counters[1]} times, o - {counters[-1]} times, and there were "
                  f"{counters[0]} draws.")

        ttt.reset()
        result = ttt.play_ai_game()
        if result < 0:
            result = -1
        elif result > 0:
            result = 1
        counters[result] += 1




from cProfile import Profile
profiler = Profile()
profiler.runcall(run_trials)
profiler.print_stats('cumulative')
# Out:
# 0 out of 10000
# stats: out of 0 games, x has won 0 times, o - 0 times, and there were 0 draws.
# 50 out of 10000
# stats: out of 50 games, x has won 28 times, o - 7 times, and there were 15 draws.
# 100 out of 10000
# stats: out of 100 games, x has won 61 times, o - 13 times, and there were 26 draws.
# 150 out of 10000
# stats: out of 150 games, x has won 89 times, o - 19 times, and there were 42 draws.
# 200 out of 10000
# stats: out of 200 games, x has won 117 times, o - 26 times, and there were 57 draws.
# 250 out of 10000
# stats: out of 250 games, x has won 150 times, o - 31 times, and there were 69 draws.
# 300 out of 10000
# stats: out of 300 games, x has won 185 times, o - 36 times, and there were 79 draws.
# 350 out of 10000
# stats: out of 350 games, x has won 216 times, o - 40 times, and there were 94 draws.
# 400 out of 10000
# stats: out of 400 games, x has won 242 times, o - 50 times, and there were 108 draws.
# 450 out of 10000
# stats: out of 450 games, x has won 261 times, o - 58 times, and there were 131 draws.
# 500 out of 10000
# stats: out of 500 games, x has won 290 times, o - 60 times, and there were 150 draws.
# 550 out of 10000
# stats: out of 550 games, x has won 324 times, o - 66 times, and there were 160 draws.
# 600 out of 10000
# stats: out of 600 games, x has won 352 times, o - 75 times, and there were 173 draws.
# 650 out of 10000
# stats: out of 650 games, x has won 385 times, o - 78 times, and there were 187 draws.
# 700 out of 10000
# stats: out of 700 games, x has won 414 times, o - 80 times, and there were 206 draws.
# 750 out of 10000
# stats: out of 750 games, x has won 439 times, o - 84 times, and there were 227 draws.
# 800 out of 10000
# stats: out of 800 games, x has won 470 times, o - 89 times, and there were 241 draws.
# 850 out of 10000
# stats: out of 850 games, x has won 499 times, o - 94 times, and there were 257 draws.
# 900 out of 10000
# stats: out of 900 games, x has won 528 times, o - 103 times, and there were 269 draws.
# 950 out of 10000
# stats: out of 950 games, x has won 553 times, o - 111 times, and there were 286 draws.
# 1000 out of 10000
# stats: out of 1000 games, x has won 577 times, o - 120 times, and there were 303 draws.
# 1050 out of 10000
# stats: out of 1050 games, x has won 610 times, o - 125 times, and there were 315 draws.
# 1100 out of 10000
# stats: out of 1100 games, x has won 635 times, o - 129 times, and there were 336 draws.
# 1150 out of 10000
# stats: out of 1150 games, x has won 661 times, o - 133 times, and there were 356 draws.
# 1200 out of 10000
# stats: out of 1200 games, x has won 689 times, o - 137 times, and there were 374 draws.
# 1250 out of 10000
# stats: out of 1250 games, x has won 716 times, o - 142 times, and there were 392 draws.
# 1300 out of 10000
# stats: out of 1300 games, x has won 744 times, o - 150 times, and there were 406 draws.
# 1350 out of 10000
# stats: out of 1350 games, x has won 766 times, o - 158 times, and there were 426 draws.
# 1400 out of 10000
# stats: out of 1400 games, x has won 792 times, o - 167 times, and there were 441 draws.
# 1450 out of 10000
# stats: out of 1450 games, x has won 823 times, o - 172 times, and there were 455 draws.
# 1500 out of 10000
# stats: out of 1500 games, x has won 849 times, o - 181 times, and there were 470 draws.
# 1550 out of 10000
# stats: out of 1550 games, x has won 878 times, o - 187 times, and there were 485 draws.
# 1600 out of 10000
# stats: out of 1600 games, x has won 909 times, o - 192 times, and there were 499 draws.
# 1650 out of 10000
# stats: out of 1650 games, x has won 940 times, o - 198 times, and there were 512 draws.
# 1700 out of 10000
# stats: out of 1700 games, x has won 966 times, o - 208 times, and there were 526 draws.
# 1750 out of 10000
# stats: out of 1750 games, x has won 996 times, o - 215 times, and there were 539 draws.
# 1800 out of 10000
# stats: out of 1800 games, x has won 1027 times, o - 216 times, and there were 557 draws.
# 1850 out of 10000
# stats: out of 1850 games, x has won 1057 times, o - 222 times, and there were 571 draws.
# 1900 out of 10000
# stats: out of 1900 games, x has won 1085 times, o - 225 times, and there were 590 draws.
# 1950 out of 10000
# stats: out of 1950 games, x has won 1112 times, o - 234 times, and there were 604 draws.
# 2000 out of 10000
# stats: out of 2000 games, x has won 1145 times, o - 239 times, and there were 616 draws.
# 2050 out of 10000
# stats: out of 2050 games, x has won 1172 times, o - 244 times, and there were 634 draws.
# 2100 out of 10000
# stats: out of 2100 games, x has won 1200 times, o - 248 times, and there were 652 draws.
# 2150 out of 10000
# stats: out of 2150 games, x has won 1228 times, o - 255 times, and there were 667 draws.
# 2200 out of 10000
# stats: out of 2200 games, x has won 1255 times, o - 264 times, and there were 681 draws.
# 2250 out of 10000
# stats: out of 2250 games, x has won 1292 times, o - 267 times, and there were 691 draws.
# 2300 out of 10000
# stats: out of 2300 games, x has won 1320 times, o - 275 times, and there were 705 draws.
# 2350 out of 10000
# stats: out of 2350 games, x has won 1342 times, o - 280 times, and there were 728 draws.
# 2400 out of 10000
# stats: out of 2400 games, x has won 1374 times, o - 284 times, and there were 742 draws.
# 2450 out of 10000
# stats: out of 2450 games, x has won 1409 times, o - 288 times, and there were 753 draws.
# 2500 out of 10000
# stats: out of 2500 games, x has won 1436 times, o - 299 times, and there were 765 draws.
# 2550 out of 10000
# stats: out of 2550 games, x has won 1464 times, o - 304 times, and there were 782 draws.
# 2600 out of 10000
# stats: out of 2600 games, x has won 1497 times, o - 307 times, and there were 796 draws.
# 2650 out of 10000
# stats: out of 2650 games, x has won 1526 times, o - 310 times, and there were 814 draws.
# 2700 out of 10000
# stats: out of 2700 games, x has won 1558 times, o - 311 times, and there were 831 draws.
# 2750 out of 10000
# stats: out of 2750 games, x has won 1589 times, o - 315 times, and there were 846 draws.
# 2800 out of 10000
# stats: out of 2800 games, x has won 1606 times, o - 324 times, and there were 870 draws.
# 2850 out of 10000
# stats: out of 2850 games, x has won 1629 times, o - 331 times, and there were 890 draws.
# 2900 out of 10000
# stats: out of 2900 games, x has won 1661 times, o - 335 times, and there were 904 draws.
# 2950 out of 10000
# stats: out of 2950 games, x has won 1689 times, o - 345 times, and there were 916 draws.
# 3000 out of 10000
# stats: out of 3000 games, x has won 1721 times, o - 350 times, and there were 929 draws.
# 3050 out of 10000
# stats: out of 3050 games, x has won 1747 times, o - 361 times, and there were 942 draws.
# 3100 out of 10000
# stats: out of 3100 games, x has won 1774 times, o - 366 times, and there were 960 draws.
# 3150 out of 10000
# stats: out of 3150 games, x has won 1803 times, o - 376 times, and there were 971 draws.
# 3200 out of 10000
# stats: out of 3200 games, x has won 1828 times, o - 385 times, and there were 987 draws.
# 3250 out of 10000
# stats: out of 3250 games, x has won 1856 times, o - 392 times, and there were 1002 draws.
# 3300 out of 10000
# stats: out of 3300 games, x has won 1887 times, o - 397 times, and there were 1016 draws.
# 3350 out of 10000
# stats: out of 3350 games, x has won 1916 times, o - 402 times, and there were 1032 draws.
# 3400 out of 10000
# stats: out of 3400 games, x has won 1951 times, o - 403 times, and there were 1046 draws.
# 3450 out of 10000
# stats: out of 3450 games, x has won 1985 times, o - 409 times, and there were 1056 draws.
# 3500 out of 10000
# stats: out of 3500 games, x has won 2014 times, o - 412 times, and there were 1074 draws.
# 3550 out of 10000
# stats: out of 3550 games, x has won 2044 times, o - 420 times, and there were 1086 draws.
# 3600 out of 10000
# stats: out of 3600 games, x has won 2071 times, o - 424 times, and there were 1105 draws.
# 3650 out of 10000
# stats: out of 3650 games, x has won 2091 times, o - 429 times, and there were 1130 draws.
# 3700 out of 10000
# stats: out of 3700 games, x has won 2115 times, o - 437 times, and there were 1148 draws.
# 3750 out of 10000
# stats: out of 3750 games, x has won 2141 times, o - 445 times, and there were 1164 draws.
# 3800 out of 10000
# stats: out of 3800 games, x has won 2173 times, o - 452 times, and there were 1175 draws.
# 3850 out of 10000
# stats: out of 3850 games, x has won 2203 times, o - 457 times, and there were 1190 draws.
# 3900 out of 10000
# stats: out of 3900 games, x has won 2235 times, o - 465 times, and there were 1200 draws.
# 3950 out of 10000
# stats: out of 3950 games, x has won 2257 times, o - 471 times, and there were 1222 draws.
# 4000 out of 10000
# stats: out of 4000 games, x has won 2289 times, o - 479 times, and there were 1232 draws.
# 4050 out of 10000
# stats: out of 4050 games, x has won 2315 times, o - 484 times, and there were 1251 draws.
# 4100 out of 10000
# stats: out of 4100 games, x has won 2344 times, o - 488 times, and there were 1268 draws.
# 4150 out of 10000
# stats: out of 4150 games, x has won 2377 times, o - 492 times, and there were 1281 draws.
# 4200 out of 10000
# stats: out of 4200 games, x has won 2400 times, o - 503 times, and there were 1297 draws.
# 4250 out of 10000
# stats: out of 4250 games, x has won 2435 times, o - 504 times, and there were 1311 draws.
# 4300 out of 10000
# stats: out of 4300 games, x has won 2463 times, o - 511 times, and there were 1326 draws.
# 4350 out of 10000
# stats: out of 4350 games, x has won 2492 times, o - 515 times, and there were 1343 draws.
# 4400 out of 10000
# stats: out of 4400 games, x has won 2523 times, o - 522 times, and there were 1355 draws.
# 4450 out of 10000
# stats: out of 4450 games, x has won 2555 times, o - 528 times, and there were 1367 draws.
# 4500 out of 10000
# stats: out of 4500 games, x has won 2585 times, o - 529 times, and there were 1386 draws.
# 4550 out of 10000
# stats: out of 4550 games, x has won 2613 times, o - 534 times, and there were 1403 draws.
# 4600 out of 10000
# stats: out of 4600 games, x has won 2642 times, o - 541 times, and there were 1417 draws.
# 4650 out of 10000
# stats: out of 4650 games, x has won 2668 times, o - 549 times, and there were 1433 draws.
# 4700 out of 10000
# stats: out of 4700 games, x has won 2695 times, o - 556 times, and there were 1449 draws.
# 4750 out of 10000
# stats: out of 4750 games, x has won 2722 times, o - 564 times, and there were 1464 draws.
# 4800 out of 10000
# stats: out of 4800 games, x has won 2747 times, o - 569 times, and there were 1484 draws.
# 4850 out of 10000
# stats: out of 4850 games, x has won 2779 times, o - 575 times, and there were 1496 draws.
# 4900 out of 10000
# stats: out of 4900 games, x has won 2810 times, o - 578 times, and there were 1512 draws.
# 4950 out of 10000
# stats: out of 4950 games, x has won 2840 times, o - 583 times, and there were 1527 draws.
# 5000 out of 10000
# stats: out of 5000 games, x has won 2867 times, o - 588 times, and there were 1545 draws.
# 5050 out of 10000
# stats: out of 5050 games, x has won 2892 times, o - 596 times, and there were 1562 draws.
# 5100 out of 10000
# stats: out of 5100 games, x has won 2922 times, o - 602 times, and there were 1576 draws.
# 5150 out of 10000
# stats: out of 5150 games, x has won 2951 times, o - 608 times, and there were 1591 draws.
# 5200 out of 10000
# stats: out of 5200 games, x has won 2978 times, o - 611 times, and there were 1611 draws.
# 5250 out of 10000
# stats: out of 5250 games, x has won 3004 times, o - 620 times, and there were 1626 draws.
# 5300 out of 10000
# stats: out of 5300 games, x has won 3036 times, o - 627 times, and there were 1637 draws.
# 5350 out of 10000
# stats: out of 5350 games, x has won 3067 times, o - 629 times, and there were 1654 draws.
# 5400 out of 10000
# stats: out of 5400 games, x has won 3095 times, o - 631 times, and there were 1674 draws.
# 5450 out of 10000
# stats: out of 5450 games, x has won 3123 times, o - 637 times, and there were 1690 draws.
# 5500 out of 10000
# stats: out of 5500 games, x has won 3157 times, o - 645 times, and there were 1698 draws.
# 5550 out of 10000
# stats: out of 5550 games, x has won 3183 times, o - 651 times, and there were 1716 draws.
# 5600 out of 10000
# stats: out of 5600 games, x has won 3219 times, o - 655 times, and there were 1726 draws.
# 5650 out of 10000
# stats: out of 5650 games, x has won 3248 times, o - 658 times, and there were 1744 draws.
# 5700 out of 10000
# stats: out of 5700 games, x has won 3281 times, o - 661 times, and there were 1758 draws.
# 5750 out of 10000
# stats: out of 5750 games, x has won 3311 times, o - 670 times, and there were 1769 draws.
# 5800 out of 10000
# stats: out of 5800 games, x has won 3339 times, o - 682 times, and there were 1779 draws.
# 5850 out of 10000
# stats: out of 5850 games, x has won 3365 times, o - 689 times, and there were 1796 draws.
# 5900 out of 10000
# stats: out of 5900 games, x has won 3395 times, o - 695 times, and there were 1810 draws.
# 5950 out of 10000
# stats: out of 5950 games, x has won 3422 times, o - 704 times, and there were 1824 draws.
# 6000 out of 10000
# stats: out of 6000 games, x has won 3449 times, o - 711 times, and there were 1840 draws.
# 6050 out of 10000
# stats: out of 6050 games, x has won 3482 times, o - 714 times, and there were 1854 draws.
# 6100 out of 10000
# stats: out of 6100 games, x has won 3506 times, o - 720 times, and there were 1874 draws.
# 6150 out of 10000
# stats: out of 6150 games, x has won 3536 times, o - 725 times, and there were 1889 draws.
# 6200 out of 10000
# stats: out of 6200 games, x has won 3564 times, o - 732 times, and there were 1904 draws.
# 6250 out of 10000
# stats: out of 6250 games, x has won 3599 times, o - 735 times, and there were 1916 draws.
# 6300 out of 10000
# stats: out of 6300 games, x has won 3632 times, o - 738 times, and there were 1930 draws.
# 6350 out of 10000
# stats: out of 6350 games, x has won 3660 times, o - 746 times, and there were 1944 draws.
# 6400 out of 10000
# stats: out of 6400 games, x has won 3688 times, o - 749 times, and there were 1963 draws.
# 6450 out of 10000
# stats: out of 6450 games, x has won 3719 times, o - 754 times, and there were 1977 draws.
# 6500 out of 10000
# stats: out of 6500 games, x has won 3747 times, o - 759 times, and there were 1994 draws.
# 6550 out of 10000
# stats: out of 6550 games, x has won 3779 times, o - 764 times, and there were 2007 draws.
# 6600 out of 10000
# stats: out of 6600 games, x has won 3810 times, o - 770 times, and there were 2020 draws.
# 6650 out of 10000
# stats: out of 6650 games, x has won 3832 times, o - 774 times, and there were 2044 draws.
# 6700 out of 10000
# stats: out of 6700 games, x has won 3857 times, o - 782 times, and there were 2061 draws.
# 6750 out of 10000
# stats: out of 6750 games, x has won 3890 times, o - 786 times, and there were 2074 draws.
# 6800 out of 10000
# stats: out of 6800 games, x has won 3920 times, o - 790 times, and there were 2090 draws.
# 6850 out of 10000
# stats: out of 6850 games, x has won 3949 times, o - 797 times, and there were 2104 draws.
# 6900 out of 10000
# stats: out of 6900 games, x has won 3979 times, o - 803 times, and there were 2118 draws.
# 6950 out of 10000
# stats: out of 6950 games, x has won 4006 times, o - 808 times, and there were 2136 draws.
# 7000 out of 10000
# stats: out of 7000 games, x has won 4039 times, o - 814 times, and there were 2147 draws.
# 7050 out of 10000
# stats: out of 7050 games, x has won 4070 times, o - 819 times, and there were 2161 draws.
# 7100 out of 10000
# stats: out of 7100 games, x has won 4092 times, o - 829 times, and there were 2179 draws.
# 7150 out of 10000
# stats: out of 7150 games, x has won 4118 times, o - 835 times, and there were 2197 draws.
# 7200 out of 10000
# stats: out of 7200 games, x has won 4150 times, o - 835 times, and there were 2215 draws.
# 7250 out of 10000
# stats: out of 7250 games, x has won 4180 times, o - 840 times, and there were 2230 draws.
# 7300 out of 10000
# stats: out of 7300 games, x has won 4211 times, o - 844 times, and there were 2245 draws.
# 7350 out of 10000
# stats: out of 7350 games, x has won 4241 times, o - 850 times, and there were 2259 draws.
# 7400 out of 10000
# stats: out of 7400 games, x has won 4273 times, o - 853 times, and there were 2274 draws.
# 7450 out of 10000
# stats: out of 7450 games, x has won 4301 times, o - 856 times, and there were 2293 draws.
# 7500 out of 10000
# stats: out of 7500 games, x has won 4327 times, o - 862 times, and there were 2311 draws.
# 7550 out of 10000
# stats: out of 7550 games, x has won 4356 times, o - 865 times, and there were 2329 draws.
# 7600 out of 10000
# stats: out of 7600 games, x has won 4387 times, o - 873 times, and there were 2340 draws.
# 7650 out of 10000
# stats: out of 7650 games, x has won 4420 times, o - 880 times, and there were 2350 draws.
# 7700 out of 10000
# stats: out of 7700 games, x has won 4454 times, o - 883 times, and there were 2363 draws.
# 7750 out of 10000
# stats: out of 7750 games, x has won 4486 times, o - 888 times, and there were 2376 draws.
# 7800 out of 10000
# stats: out of 7800 games, x has won 4517 times, o - 893 times, and there were 2390 draws.
# 7850 out of 10000
# stats: out of 7850 games, x has won 4547 times, o - 901 times, and there were 2402 draws.
# 7900 out of 10000
# stats: out of 7900 games, x has won 4580 times, o - 905 times, and there were 2415 draws.
# 7950 out of 10000
# stats: out of 7950 games, x has won 4606 times, o - 916 times, and there were 2428 draws.
# 8000 out of 10000
# stats: out of 8000 games, x has won 4632 times, o - 927 times, and there were 2441 draws.
# 8050 out of 10000
# stats: out of 8050 games, x has won 4658 times, o - 932 times, and there were 2460 draws.
# 8100 out of 10000
# stats: out of 8100 games, x has won 4695 times, o - 937 times, and there were 2468 draws.
# 8150 out of 10000
# stats: out of 8150 games, x has won 4722 times, o - 944 times, and there were 2484 draws.
# 8200 out of 10000
# stats: out of 8200 games, x has won 4752 times, o - 952 times, and there were 2496 draws.
# 8250 out of 10000
# stats: out of 8250 games, x has won 4777 times, o - 957 times, and there were 2516 draws.
# 8300 out of 10000
# stats: out of 8300 games, x has won 4804 times, o - 963 times, and there were 2533 draws.
# 8350 out of 10000
# stats: out of 8350 games, x has won 4835 times, o - 967 times, and there were 2548 draws.
# 8400 out of 10000
# stats: out of 8400 games, x has won 4860 times, o - 973 times, and there were 2567 draws.
# 8450 out of 10000
# stats: out of 8450 games, x has won 4888 times, o - 982 times, and there were 2580 draws.
# 8500 out of 10000
# stats: out of 8500 games, x has won 4912 times, o - 988 times, and there were 2600 draws.
# 8550 out of 10000
# stats: out of 8550 games, x has won 4941 times, o - 997 times, and there were 2612 draws.
# 8600 out of 10000
# stats: out of 8600 games, x has won 4973 times, o - 1003 times, and there were 2624 draws.
# 8650 out of 10000
# stats: out of 8650 games, x has won 5003 times, o - 1011 times, and there were 2636 draws.
# 8700 out of 10000
# stats: out of 8700 games, x has won 5029 times, o - 1016 times, and there were 2655 draws.
# 8750 out of 10000
# stats: out of 8750 games, x has won 5057 times, o - 1023 times, and there were 2670 draws.
# 8800 out of 10000
# stats: out of 8800 games, x has won 5082 times, o - 1033 times, and there were 2685 draws.
# 8850 out of 10000
# stats: out of 8850 games, x has won 5108 times, o - 1039 times, and there were 2703 draws.
# 8900 out of 10000
# stats: out of 8900 games, x has won 5131 times, o - 1047 times, and there were 2722 draws.
# 8950 out of 10000
# stats: out of 8950 games, x has won 5165 times, o - 1052 times, and there were 2733 draws.
# 9000 out of 10000
# stats: out of 9000 games, x has won 5192 times, o - 1057 times, and there were 2751 draws.
# 9050 out of 10000
# stats: out of 9050 games, x has won 5223 times, o - 1060 times, and there were 2767 draws.
# 9100 out of 10000
# stats: out of 9100 games, x has won 5250 times, o - 1066 times, and there were 2784 draws.
# 9150 out of 10000
# stats: out of 9150 games, x has won 5281 times, o - 1075 times, and there were 2794 draws.
# 9200 out of 10000
# stats: out of 9200 games, x has won 5311 times, o - 1082 times, and there were 2807 draws.
# 9250 out of 10000
# stats: out of 9250 games, x has won 5341 times, o - 1087 times, and there were 2822 draws.
# 9300 out of 10000
# stats: out of 9300 games, x has won 5368 times, o - 1092 times, and there were 2840 draws.
# 9350 out of 10000
# stats: out of 9350 games, x has won 5396 times, o - 1100 times, and there were 2854 draws.
# 9400 out of 10000
# stats: out of 9400 games, x has won 5423 times, o - 1109 times, and there were 2868 draws.
# 9450 out of 10000
# stats: out of 9450 games, x has won 5445 times, o - 1116 times, and there were 2889 draws.
# 9500 out of 10000
# stats: out of 9500 games, x has won 5472 times, o - 1121 times, and there were 2907 draws.
# 9550 out of 10000
# stats: out of 9550 games, x has won 5502 times, o - 1124 times, and there were 2924 draws.
# 9600 out of 10000
# stats: out of 9600 games, x has won 5526 times, o - 1129 times, and there were 2945 draws.
# 9650 out of 10000
# stats: out of 9650 games, x has won 5558 times, o - 1132 times, and there were 2960 draws.
# 9700 out of 10000
# stats: out of 9700 games, x has won 5588 times, o - 1139 times, and there were 2973 draws.
# 9750 out of 10000
# stats: out of 9750 games, x has won 5616 times, o - 1147 times, and there were 2987 draws.
# 9800 out of 10000
# stats: out of 9800 games, x has won 5643 times, o - 1151 times, and there were 3006 draws.
# 9850 out of 10000
# stats: out of 9850 games, x has won 5671 times, o - 1157 times, and there were 3022 draws.
# 9900 out of 10000
# stats: out of 9900 games, x has won 5694 times, o - 1162 times, and there were 3044 draws.
# 9950 out of 10000
# stats: out of 9950 games, x has won 5714 times, o - 1176 times, and there were 3060 draws.
#          63520211 function calls (57018455 primitive calls) in 182.628 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.065    0.065  182.628  182.628 <ipython-input-11-893974592665>:15(run_trials)
#     10000    0.381    0.000  182.125    0.018 <ipython-input-4-371028b2d5d3>:107(play_ai_game)
#     37471    0.175    0.000  109.447    0.003 <ipython-input-3-eec947065e99>:9(decide_turn)
# 6210632/20008   22.231    0.000  108.244    0.005 <ipython-input-3-eec947065e99>:30(minimax)
#     38890    0.226    0.000   70.827    0.002 <ipython-input-10-0263e2c76d41>:31(decide_turn)
#     38890    0.278    0.000   70.600    0.002 dqn.py:225(forward)
#     38890    0.148    0.000   68.796    0.002 dqn.py:68(compute_q_values)
#     38890    0.207    0.000   68.466    0.002 dqn.py:62(compute_batch_q_values)
#     38890    0.285    0.000   67.741    0.002 training.py:1257(predict_on_batch)
#     38890    0.274    0.000   65.092    0.002 tensorflow_backend.py:2657(__call__)
#   6302012   27.203    0.000   64.951    0.000 <ipython-input-4-371028b2d5d3>:94(evaluate)
#     38890    0.679    0.000   56.835    0.001 tensorflow_backend.py:2596(_call)
#     38890    0.298    0.000   49.029    0.001 session.py:1445(__call__)
#     38890   48.107    0.001   48.107    0.001 {built-in method _pywrap_tensorflow_internal.TF_SessionRunCallable}
#  25208048   37.747    0.000   37.747    0.000 <ipython-input-4-371028b2d5d3>:104(<genexpr>)
#   3388806   20.414    0.000   23.039    0.000 <ipython-input-3-eec947065e99>:20(empty_cells)
#     77780    3.949    0.000   14.011    0.000 tensorflow_backend.py:154(get_session)
#   7661341    4.070    0.000    4.070    0.000 {built-in method builtins.getattr}
# 311138/155572    0.349    0.000    3.371    0.000 {built-in method builtins.next}
#    155566    1.010    0.000    3.194    0.000 ops.py:5245(get_controller)
#   6635761    2.771    0.000    2.771    0.000 {method 'append' of 'list' objects}
# 155569/77786    0.173    0.000    2.291    0.000 contextlib.py:79(__enter__)
#     38890    0.332    0.000    2.021    0.000 training.py:637(_standardize_user_data)
#     77780    0.141    0.000    1.523    0.000 variables.py:1390(global_variables)
#     77780    0.190    0.000    1.381    0.000 ops.py:5855(get_collection)
# 155569/77786    0.280    0.000    1.287    0.000 contextlib.py:85(__exit__)
#     38890    0.482    0.000    1.125    0.000 training_utils.py:31(standardize_input_data)
#     38890    0.380    0.000    1.018    0.000 memory.py:121(get_recent_state)
#     77780    0.431    0.000    0.800    0.000 ops.py:3915(get_collection)
#    155569    0.265    0.000    0.771    0.000 contextlib.py:157(helper)
#     77780    0.710    0.000    0.710    0.000 {built-in method numpy.core.multiarray.array}
#     77783    0.159    0.000    0.637    0.000 ops.py:3809(as_default)
#    116670    0.255    0.000    0.536    0.000 tensorflow_backend.py:477(is_tensor)
#    155565    0.293    0.000    0.513    0.000 context.py:594(executing_eagerly)
#    155569    0.402    0.000    0.507    0.000 contextlib.py:59(__init__)
#     14981    0.126    0.000    0.506    0.000 <ipython-input-2-a63b89b084c3>:8(decide_turn)
#     38890    0.084    0.000    0.501    0.000 dqn.py:56(process_state_batch)
#     38890    0.100    0.000    0.480    0.000 policy.py:167(select_action)
#     38890    0.138    0.000    0.454    0.000 network.py:441(stateful)
#     77783    0.207    0.000    0.453    0.000 context.py:117(push)
#    116670    0.222    0.000    0.451    0.000 memory.py:86(zeroed_observation)
#     77787    0.112    0.000    0.391    0.000 ops.py:5522(get_default_graph)
#     38890    0.100    0.000    0.380    0.000 fromnumeric.py:976(argmax)
#     38891    0.210    0.000    0.374    0.000 errors_impl.py:513(__exit__)
#     10000    0.059    0.000    0.373    0.000 <ipython-input-4-371028b2d5d3>:29(reset)
#    155566    0.260    0.000    0.369    0.000 ops.py:5055(get_controller)
#    155561    0.170    0.000    0.369    0.000 {built-in method builtins.any}
#     38890    0.066    0.000    0.368    0.000 training_utils.py:91(<listcomp>)
#     38890    0.053    0.000    0.346    0.000 numeric.py:433(asarray)
#    728746    0.340    0.000    0.340    0.000 {built-in method builtins.len}
#     77780    0.099    0.000    0.321    0.000 ops.py:6118(_assert_collection_is_ok)
#     38890    0.093    0.000    0.302    0.000 training_utils.py:15(standardize_single_array)
#    155567    0.223    0.000    0.296    0.000 ops.py:5038(get_default)
#    468324    0.295    0.000    0.295    0.000 {built-in method builtins.isinstance}
#     77780    0.139    0.000    0.284    0.000 ops.py:5125(get_default_session)
#     38890    0.083    0.000    0.280    0.000 fromnumeric.py:49(_wrapfunc)
#     77787    0.129    0.000    0.279    0.000 ops.py:5225(get_default)
#     76361    0.268    0.000    0.268    0.000 <ipython-input-4-371028b2d5d3>:78(try_make_turn)
#    388907    0.267    0.000    0.267    0.000 {built-in method builtins.hasattr}
#     38891    0.094    0.000    0.251    0.000 errors_impl.py:509(__enter__)
#     34036    0.078    0.000    0.235    0.000 random.py:253(choice)
#     53871    0.220    0.000    0.220    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#    116670    0.135    0.000    0.217    0.000 ops.py:128(is_dense_tensor_like)
#     38891    0.056    0.000    0.198    0.000 training.py:545(_uses_dynamic_learning_phase)
#     38890    0.106    0.000    0.188    0.000 network.py:443(<listcomp>)
#     77783    0.103    0.000    0.182    0.000 <string>:12(__new__)
#     77780    0.082    0.000    0.173    0.000 tensorflow_backend.py:2659(<genexpr>)
#     38890    0.168    0.000    0.168    0.000 {method 'argmax' of 'numpy.ndarray' objects}
#    126670    0.164    0.000    0.164    0.000 {built-in method numpy.core.multiarray.zeros}
#    311133    0.164    0.000    0.164    0.000 context.py:560(context)
#     38891    0.073    0.000    0.157    0.000 c_api_util.py:30(__init__)
#     77783    0.106    0.000    0.153    0.000 context.py:133(pop)
#     34036    0.091    0.000    0.143    0.000 random.py:223(_randbelow)
#     38891    0.089    0.000    0.142    0.000 network.py:435(uses_learning_phase)
#    155567    0.134    0.000    0.134    0.000 context.py:302(executing_eagerly)
#    155567    0.114    0.000    0.114    0.000 {method 'pop' of 'list' objects}
#     38891    0.084    0.000    0.104    0.000 sequential.py:94(layers)
#     38891    0.064    0.000    0.100    0.000 c_api_util.py:33(__del__)
#    116670    0.095    0.000    0.095    0.000 {method 'insert' of 'list' objects}
#     38890    0.060    0.000    0.091    0.000 tensorflow_backend.py:309(is_sparse)
#     14981    0.087    0.000    0.087    0.000 <ipython-input-2-a63b89b084c3>:10(<listcomp>)
#     38891    0.084    0.000    0.084    0.000 {built-in method _pywrap_tensorflow_internal.TF_NewStatus}
#    155566    0.083    0.000    0.083    0.000 context.py:544(context_switches)
#     77783    0.079    0.000    0.079    0.000 {built-in method __new__ of type object at 0x55b5b6460d60}
#     38890    0.052    0.000    0.076    0.000 training.py:528(_make_predict_function)
#     38890    0.053    0.000    0.070    0.000 generic_utils.py:464(unpack_singleton)
#     38890    0.049    0.000    0.068    0.000 dtypes.py:652(as_dtype)
#       400    0.004    0.000    0.066    0.000 {built-in method builtins.print}
#     38891    0.064    0.000    0.064    0.000 {built-in method _pywrap_tensorflow_internal.TF_GetCode}
#      1600    0.007    0.000    0.062    0.000 iostream.py:366(write)
#         1    0.000    0.000    0.059    0.059 tensorflow_backend.py:2549(_make_callable)
#         1    0.000    0.000    0.059    0.059 session.py:1469(_make_callable_from_options)
#     77780    0.050    0.000    0.050    0.000 session.py:717(graph)
#      1800    0.008    0.000    0.049    0.000 iostream.py:195(schedule)
#     77795    0.048    0.000    0.048    0.000 {method 'get' of 'dict' objects}
#     38890    0.048    0.000    0.048    0.000 ops.py:320(dtype)
#     77786    0.046    0.000    0.046    0.000 ops.py:3309(building_function)
#     38890    0.044    0.000    0.044    0.000 dtypes.py:129(as_numpy_dtype)
#     38891    0.036    0.000    0.036    0.000 {built-in method _pywrap_tensorflow_internal.TF_DeleteStatus}
#     38891    0.034    0.000    0.034    0.000 network.py:439(<listcomp>)
#     45476    0.034    0.000    0.034    0.000 {method 'getrandbits' of '_random.Random' objects}
#         1    0.000    0.000    0.032    0.032 session.py:1429(__init__)
#         1    0.032    0.032    0.032    0.032 {built-in method _pywrap_tensorflow_internal.TF_SessionMakeCallable}
#     38890    0.029    0.000    0.029    0.000 dqn.py:362(test_policy)
#      1800    0.029    0.000    0.029    0.000 socket.py:333(send)
#     38890    0.028    0.000    0.028    0.000 base_layer.py:189(built)
#         1    0.000    0.000    0.026    0.026 session.py:1337(_extend_graph)
#         1    0.026    0.026    0.026    0.026 {built-in method _pywrap_tensorflow_internal.ExtendSession}
#     38890    0.026    0.000    0.026    0.000 training.py:726(<genexpr>)
#     14981    0.018    0.000    0.018    0.000 {built-in method builtins.sum}
#     34036    0.018    0.000    0.018    0.000 {method 'bit_length' of 'int' objects}
#      1600    0.001    0.000    0.012    0.000 iostream.py:313(_schedule_flush)
#     10000    0.010    0.000    0.010    0.000 {method 'random' of '_random.Random' objects}
#      1800    0.004    0.000    0.009    0.000 threading.py:1104(is_alive)
#      1800    0.002    0.000    0.004    0.000 threading.py:1062(_wait_for_tstate_lock)
#      1600    0.003    0.000    0.003    0.000 iostream.py:300(_is_master_process)
#         1    0.000    0.000    0.002    0.002 tensorflow_backend.py:2675(function)
#      1800    0.002    0.000    0.002    0.000 {method 'acquire' of '_thread.lock' objects}
#      1800    0.002    0.000    0.002    0.000 iostream.py:93(_event_pipe)
#         1    0.000    0.000    0.001    0.001 tensorflow_backend.py:2500(__init__)
#         1    0.000    0.000    0.001    0.001 control_flow_ops.py:3321(group)
#         1    0.000    0.000    0.001    0.001 gen_control_flow_ops.py:486(no_op)
#         1    0.000    0.000    0.001    0.001 op_def_library.py:339(_apply_op_helper)
#      1800    0.001    0.000    0.001    0.000 threading.py:506(is_set)
#         1    0.000    0.000    0.001    0.001 ops.py:3315(create_op)
#      1800    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#      1600    0.001    0.000    0.001    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.001    0.001 ops.py:1596(__init__)
#         1    0.000    0.000    0.001    0.001 ops.py:1528(_create_c_op)
#         1    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TF_FinishOperation}
#         2    0.000    0.000    0.000    0.000 generic_utils.py:244(has_arg)
#         2    0.000    0.000    0.000    0.000 inspect.py:3035(signature)
#         2    0.000    0.000    0.000    0.000 inspect.py:2783(from_callable)
#         2    0.000    0.000    0.000    0.000 inspect.py:2176(_signature_from_callable)
#         2    0.000    0.000    0.000    0.000 ops.py:5936(__enter__)
#         2    0.000    0.000    0.000    0.000 inspect.py:2095(_signature_from_function)
#         1    0.000    0.000    0.000    0.000 ops.py:2955(_extract_stack)
#         1    0.000    0.000    0.000    0.000 ops.py:3438(_create_op_helper)
#         4    0.000    0.000    0.000    0.000 ops.py:4006(name_scope)
#         1    0.000    0.000    0.000    0.000 ops.py:4998(control_dependencies)
#         2    0.000    0.000    0.000    0.000 ops.py:5987(__exit__)
#        11    0.000    0.000    0.000    0.000 inspect.py:2435(__init__)
#         2    0.000    0.000    0.000    0.000 inspect.py:2714(__init__)
#         1    0.000    0.000    0.000    0.000 ops.py:4531(control_dependencies)
#         3    0.000    0.000    0.000    0.000 ops.py:5576(_get_graph_from_inputs)
#         1    0.000    0.000    0.000    0.000 ops.py:1493(_NodeDef)
#         7    0.000    0.000    0.000    0.000 ops.py:1850(name)
#         1    0.000    0.000    0.000    0.000 ops.py:3004(_add_op)
#         2    0.000    0.000    0.000    0.000 ops.py:330(name)
#         7    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TF_OperationName}
#         1    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TF_NewBufferFromString}
#         1    0.000    0.000    0.000    0.000 ops.py:1762(_control_flow_post_processing)
#         1    0.000    0.000    0.000    0.000 {method 'SerializeToString' of 'google.protobuf.pyext._message.CMessage' objects}
#        13    0.000    0.000    0.000    0.000 inspect.py:2759(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TF_NewOperation}
#         2    0.000    0.000    0.000    0.000 inspect.py:485(unwrap)
#         3    0.000    0.000    0.000    0.000 compat.py:48(as_bytes)
#        41    0.000    0.000    0.000    0.000 ops.py:2991(_extract_frame_info)
#         1    0.000    0.000    0.000    0.000 ops.py:3557(as_graph_element)
#         1    0.000    0.000    0.000    0.000 ops.py:2107(inputs)
#         1    0.000    0.000    0.000    0.000 ops.py:3592(_as_graph_element_locked)
#         1    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TF_AddControlInput}
#         1    0.000    0.000    0.000    0.000 pywrap_tensorflow_internal.py:799(<lambda>)
#         2    0.000    0.000    0.000    0.000 ops.py:2218(type)
#         1    0.000    0.000    0.000    0.000 ops.py:4488(_control_dependencies_for_inputs)
#         1    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TF_OperationNumOutputs}
#         3    0.000    0.000    0.000    0.000 {method 'match' of '_sre.SRE_Pattern' objects}
#         2    0.000    0.000    0.000    0.000 {method 'ByteSize' of 'google.protobuf.pyext._message.CMessage' objects}
#         5    0.000    0.000    0.000    0.000 ops.py:3994(_name_stack)
#         1    0.000    0.000    0.000    0.000 ops.py:4121(unique_name)
#         2    0.000    0.000    0.000    0.000 ops.py:5922(__init__)
#         1    0.000    0.000    0.000    0.000 pywrap_tensorflow_internal.py:58(_swig_setattr)
#         1    0.000    0.000    0.000    0.000 ops.py:4522(_record_op_seen_by_control_dependencies)
#        11    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 network.py:308(__setattr__)
#         4    0.000    0.000    0.000    0.000 compat.py:70(as_text)
#         1    0.000    0.000    0.000    0.000 ops.py:4446(__enter__)
#         1    0.000    0.000    0.000    0.000 ops.py:4456(__exit__)
#         2    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TF_OperationOpType}
#         1    0.000    0.000    0.000    0.000 pywrap_tensorflow_internal.py:39(_swig_setattr_nondynamic)
#         1    0.000    0.000    0.000    0.000 six.py:586(iteritems)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'google.protobuf.pyext._message.RepeatedScalarContainer' objects}
#         6    0.000    0.000    0.000    0.000 ops.py:4907(_control_dependencies_stack)
#         4    0.000    0.000    0.000    0.000 inspect.py:159(isfunction)
#         2    0.000    0.000    0.000    0.000 inspect.py:505(_is_wrapper)
#         4    0.000    0.000    0.000    0.000 ops.py:4001(_name_stack)
#         1    0.000    0.000    0.000    0.000 ops.py:4342(_apply_device_functions)
#         1    0.000    0.000    0.000    0.000 ops.py:4477(_pop_control_dependencies_controller)
#         1    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TF_DeleteBuffer}
#        11    0.000    0.000    0.000    0.000 inspect.py:2484(name)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:676(items)
#         1    0.000    0.000    0.000    0.000 network.py:451(state_updates)
#         1    0.000    0.000    0.000    0.000 op_def_library.py:83(_Flatten)
#         1    0.000    0.000    0.000    0.000 ops.py:1774(_reconstruct_sequence_inputs)
#         1    0.000    0.000    0.000    0.000 ops.py:3784(_next_id)
#         1    0.000    0.000    0.000    0.000 ops.py:4481(_current_control_dependencies)
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 ops.py:109(_as_graph_element)
#         1    0.000    0.000    0.000    0.000 ops.py:325(graph)
#         2    0.000    0.000    0.000    0.000 ops.py:2741(_name_from_scope_name)
#         3    0.000    0.000    0.000    0.000 ops.py:2995(_check_not_finalized)
#         3    0.000    0.000    0.000    0.000 ops.py:3030(_c_graph)
#         1    0.000    0.000    0.000    0.000 ops.py:4411(__init__)
#         1    0.000    0.000    0.000    0.000 ops.py:4468(add_op)
#         1    0.000    0.000    0.000    0.000 ops.py:4474(_push_control_dependencies_controller)
#         3    0.000    0.000    0.000    0.000 ops.py:5232(_GetGlobalDefaultGraph)
#         1    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.GetOperationInputs}
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:742(__iter__)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.exc_info}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         3    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 op_def_library.py:248(_MaybeColocateWith)
#         1    0.000    0.000    0.000    0.000 ops.py:2087(__init__)
#         1    0.000    0.000    0.000    0.000 ops.py:2090(__iter__)
#         6    0.000    0.000    0.000    0.000 inspect.py:2496(kind)
#         3    0.000    0.000    0.000    0.000 inspect.py:2789(parameters)
#         1    0.000    0.000    0.000    0.000 _collections_abc.py:698(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 op_def_library.py:781(<listcomp>)
#         1    0.000    0.000    0.000    0.000 op_def_library.py:86(<listcomp>)
#         1    0.000    0.000    0.000    0.000 op_def_library.py:88(<listcomp>)
#         1    0.000    0.000    0.000    0.000 ops.py:1748(<listcomp>)
#         1    0.000    0.000    0.000    0.000 ops.py:1755(<listcomp>)
#         3    0.000    0.000    0.000    0.000 ops.py:1858(_id)
#         1    0.000    0.000    0.000    0.000 ops.py:2115(<listcomp>)
#         1    0.000    0.000    0.000    0.000 ops.py:3379(<listcomp>)
#         1    0.000    0.000    0.000    0.000 ops.py:4464(control_inputs)
#         1    0.000    0.000    0.000    0.000 ops.py:4519(<listcomp>)
#         1    0.000    0.000    0.000    0.000 ops.py:4870(_device_function_stack)
#         1    0.000    0.000    0.000    0.000 ops.py:4889(_colocation_stack)
#         1    0.000    0.000    0.000    0.000 tensorflow_backend.py:2537(<listcomp>)
#         1    0.000    0.000    0.000    0.000 pywrap_tensorflow_internal.py:823(<lambda>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 ops.py:315(op)
#         1    0.000    0.000    0.000    0.000 ops.py:1682(<genexpr>)
#         1    0.000    0.000    0.000    0.000 ops.py:2058(_recompute_node_def)
#         2    0.000    0.000    0.000    0.000 ops.py:2227(graph)
#         1    0.000    0.000    0.000    0.000 ops.py:3108(_get_control_flow_context)
